# %%
# %load_ext sql

# %%
from dotenv import load_dotenv
import os

load_dotenv()

user = os.getenv("MYSQL_USER")
password = os.getenv("MYSQL_PASSWORD")
host = os.getenv("MYSQL_HOST")
port = os.getenv("MYSQL_PORT")
db = os.getenv("MYSQL_DB")

connection_str = f"mysql+pymysql://{user}:{password}@{host}:{port}/{db}"

# %sql $connection_str

# %% [markdown]
# ## 1. Scenario Q1
# ### Analysis of most active users
# You are a Data Analyst at Twitter and are tasked with analysing user engagement. You
# need to find out which users have the highest engagement on the platform. For this
# analysis, consider a user to be engaged if they have sent messages, liked tweets,
# been mentioned, received notifications, and retweeted tweets

# %%
# %%sql
# SELECT
#     u.UserID, u.Username, u.FullName,
#     COUNT(m.SenderID) AS total_messages_sent,
#     COUNT(l.LikeID) AS total_liked_tweets,
#     COUNT(men.MentionedUserID) AS total_mentions,
#     COUNT(n.NotificationID) AS total_notifications_received,
#     COUNT(r.RetweetID) AS total_retweets
# FROM
#     users u
# INNER JOIN directmessages m
# ON u.UserID = m.SenderID
# INNER JOIN likes l
# ON u.UserID = l.LikeID
# INNER JOIN mentions men
# ON u.UserID = men.MentionedUserID
# INNER JOIN notifications n
# ON u.UserID = n.NotificationID
# INNER JOIN retweets r
# ON u.UserID = r.RetweetID
# GROUP BY
#     u.UserID
# ORDER BY
#     total_messages_sent DESC, total_liked_tweets DESC, total_mentions DESC, total_notifications_received DESC, total_retweets DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 207 rows affected.
# [(397.0, 'joseph47', 'Douglas Nichols', 15, 15, 15, 15, 15),
#  (258.0, 'christopher66', 'James Gomez', 9, 9, 9, 9, 9),
#  (268.0, 'rachelflores', 'Michelle Myers MD', 8, 8, 8, 8, 8),
#  (300.0, 'michael20', 'Penny Curtis', 8, 8, 8, 8, 8),
#  (461.0, 'gkelly', 'Jeffrey Meadows', 8, 8, 8, 8, 8),
#  (19.0, 'trevorstewart', 'Brandy Hall', 6, 6, 6, 6, 6),
#  (132.0, 'qparks', 'Barbara Rogers', 6, 6, 6, 6, 6),
#  (161.0, 'john47', 'Jaime Daniels', 6, 6, 6, 6, 6),
#  (296.0, 'austin10', 'Brandon Austin', 6, 6, 6, 6, 6),
#  (321.0, 'bryceguerra', 'Tonya Andrews', 6, 6, 6, 6, 6),
#  (322.0, 'erika27', 'Sarah Anderson', 6, 6, 6, 6, 6),
#  (411.0, 'stevensjoyce', 'Cody Colon', 6, 6, 6, 6, 6),
#  (431.0, 'stevenfrancis', 'James Brandt', 6, 6, 6, 6, 6),
#  (438.0, 'fmitchell', 'Michael Walker', 6, 6, 6, 6, 6),
#  (448.0, 'kellywhite', 'Andre Jacobs', 6, 6, 6, 6, 6),
#  (472.0, 'smithshelley', 'John Glenn', 6, 6, 6, 6, 6),
#  (475.0, 'mrodgers', 'Steven Perry', 6, 6, 6, 6, 6),
#  (27.0, 'vpierce', 'Anne Lopez', 4, 4, 4, 4, 4),
#  (39.0, 'jonesdavid', 'Alexander Wilson', 4, 4, 4, 4, 4),
#  (81.0, 'warrenvictoria', 'Scott Davis', 4, 4, 4, 4, 4),
#  (105.0, 'becky91', 'Jacob Young', 4, 4, 4, 4, 4),
#  (130.0, 'randydavis', 'Jason Wright', 4, 4, 4, 4, 4),
#  (157.0, 'utorres', 'Ian Schneider', 4, 4, 4, 4, 4),
#  (175.0, 'wendy53', 'Kevin Bean', 4, 4, 4, 4, 4),
#  (183.0, 'jamierobinson', 'Bobby Wallace', 4, 4, 4, 4, 4),
#  (246.0, 'dbaker', 'Ryan Jackson', 4, 4, 4, 4, 4),
#  (320.0, 'melissabrown', 'Brandy Carpenter', 4, 4, 4, 4, 4),
#  (333.0, 'debraandrews', 'Renee Hicks', 4, 4, 4, 4, 4),
#  (340.0, 'fisherjason', 'Amber Alexander', 4, 4, 4, 4, 4),
#  (353.0, 'hickmancarrie', 'Tina Lopez', 4, 4, 4, 4, 4),
#  (354.0, 'emilymiles', 'Robert Brown', 4, 4, 4, 4, 4),
#  (380.0, 'austin82', 'Thomas Hunter', 4, 4, 4, 4, 4),
#  (396.0, 'esparzacarlos', 'Thomas Richardson', 4, 4, 4, 4, 4),
#  (398.0, 'brianaryan', 'Jon Russell', 4, 4, 4, 4, 4),
#  (420.0, 'sanchezamber', 'Melissa Mack', 4, 4, 4, 4, 4),
#  (441.0, 'chad61', 'Mark Robbins', 4, 4, 4, 4, 4),
#  (445.0, 'stephanie41', 'Kevin Cook', 4, 4, 4, 4, 4),
#  (449.0, 'dennis52', 'Beth Preston', 4, 4, 4, 4, 4),
#  (482.0, 'johnsonjason', 'Crystal Coleman', 4, 4, 4, 4, 4),
#  (488.0, 'vincentmadden', 'Angel Moore', 4, 4, 4, 4, 4),
#  (493.0, 'markcobb', 'Robert Holt', 4, 4, 4, 4, 4),
#  (52.0, 'debrabranch', 'Justin Baker', 3, 3, 3, 3, 3),
#  (78.0, 'yflores', 'Denise Case', 3, 3, 3, 3, 3),
#  (82.0, 'christielarson', 'Deanna Farmer', 3, 3, 3, 3, 3),
#  (90.0, 'jeffreymorrow', 'Mike Boone', 3, 3, 3, 3, 3),
#  (163.0, 'awebb', 'Brandon Blake', 3, 3, 3, 3, 3),
#  (174.0, 'mharrell', 'Vanessa Smith', 3, 3, 3, 3, 3),
#  (176.0, 'karenmiller', 'Christopher Zimmerman', 3, 3, 3, 3, 3),
#  (188.0, 'emily67', 'Sydney Lutz', 3, 3, 3, 3, 3),
#  (194.0, 'mckeedavid', 'Marcus Brown', 3, 3, 3, 3, 3),
#  (227.0, 'baileyirwin', 'Alan Jones', 3, 3, 3, 3, 3),
#  (274.0, 'cjackson', 'Miranda Gray', 3, 3, 3, 3, 3),
#  (330.0, 'charleslane', 'John Ortega', 3, 3, 3, 3, 3),
#  (331.0, 'agreen', 'Olivia Garner', 3, 3, 3, 3, 3),
#  (347.0, 'bcampbell', 'James Snow', 3, 3, 3, 3, 3),
#  (370.0, 'wbrown', 'Angela Carroll', 3, 3, 3, 3, 3),
#  (387.0, 'conwayalex', 'Melvin Smith', 3, 3, 3, 3, 3),
#  (390.0, 'handerson', 'Steven Perez', 3, 3, 3, 3, 3),
#  (393.0, 'anelson', 'Jason Greer', 3, 3, 3, 3, 3),
#  (462.0, 'michele67', 'Brandon Howard', 3, 3, 3, 3, 3),
#  (491.0, 'johnsonmonica', 'Cheyenne Aguirre', 3, 3, 3, 3, 3),
#  (4.0, 'tinakelly', 'Laura Taylor', 2, 2, 2, 2, 2),
#  (18.0, 'joneskaren', 'Melissa Monroe', 2, 2, 2, 2, 2),
#  (21.0, 'cbaker', 'Robin Bailey', 2, 2, 2, 2, 2),
#  (22.0, 'donna98', 'Brittany Valenzuela', 2, 2, 2, 2, 2),
#  (26.0, 'reyesmark', 'Jason Villegas', 2, 2, 2, 2, 2),
#  (28.0, 'john25', 'Cynthia Wyatt', 2, 2, 2, 2, 2),
#  (62.0, 'kevin45', 'Jeffrey Carpenter', 2, 2, 2, 2, 2),
#  (76.0, 'orodriguez', 'David Meyer', 2, 2, 2, 2, 2),
#  (80.0, 'tayloralexis', 'Lisa Davis', 2, 2, 2, 2, 2),
#  (113.0, 'stevencruz', 'Jennifer Perry', 2, 2, 2, 2, 2),
#  (114.0, 'smithmary', 'Stephen Moran', 2, 2, 2, 2, 2),
#  (120.0, 'jwalker', 'Randy Baker', 2, 2, 2, 2, 2),
#  (121.0, 'smithjustin', 'Vincent Miller', 2, 2, 2, 2, 2),
#  (123.0, 'juliecox', 'James Huber', 2, 2, 2, 2, 2),
#  (126.0, 'trevorbarnes', 'Stephen Tran', 2, 2, 2, 2, 2),
#  (128.0, 'deckeralexis', 'David Moss', 2, 2, 2, 2, 2),
#  (138.0, 'kwilliams', 'Julie Garcia', 2, 2, 2, 2, 2),
#  (149.0, 'brandi33', 'Steven Vazquez', 2, 2, 2, 2, 2),
#  (150.0, 'brittany96', 'Karen Lang', 2, 2, 2, 2, 2),
#  (152.0, 'matthew81', 'Brett Morales', 2, 2, 2, 2, 2),
#  (154.0, 'williambeck', 'Brittany Camacho', 2, 2, 2, 2, 2),
#  (156.0, 'devinchaney', 'Olivia Riley', 2, 2, 2, 2, 2),
#  (159.0, 'wcurry', 'Hector White', 2, 2, 2, 2, 2),
#  (160.0, 'ohernandez', 'Chris Little MD', 2, 2, 2, 2, 2),
#  (165.0, 'marciaatkinson', 'Holly Harrell DDS', 2, 2, 2, 2, 2),
#  (178.0, 'michaellawrence', 'Shelby Brown', 2, 2, 2, 2, 2),
#  (184.0, 'smithphilip', 'Tiffany Patterson DDS', 2, 2, 2, 2, 2),
#  (186.0, 'mark01', 'Christina Lewis', 2, 2, 2, 2, 2),
#  (197.0, 'jennifer82', 'Paul Kemp', 2, 2, 2, 2, 2),
#  (200.0, 'frankdaniel', 'Robert Moreno', 2, 2, 2, 2, 2),
#  (203.0, 'murraymichael', 'Mary Bullock', 2, 2, 2, 2, 2),
#  (204.0, 'tiffany34', 'Derrick Henderson MD', 2, 2, 2, 2, 2),
#  (205.0, 'griffinjames', 'Cody Chavez', 2, 2, 2, 2, 2),
#  (207.0, 'melindahouston', 'James Weaver', 2, 2, 2, 2, 2),
#  (209.0, 'ronaldjones', 'Melanie Perez', 2, 2, 2, 2, 2),
#  (212.0, 'parrishmichelle', 'Katrina Thomas', 2, 2, 2, 2, 2),
#  (216.0, 'maria94', 'Kevin Best', 2, 2, 2, 2, 2),
#  (218.0, 'dawnvaldez', 'Alicia Hurley', 2, 2, 2, 2, 2),
#  (231.0, 'amorales', 'Alexander Sellers', 2, 2, 2, 2, 2),
#  (256.0, 'amberhartman', 'Ernest Garcia', 2, 2, 2, 2, 2),
#  (266.0, 'hlawrence', 'Isabel Gamble', 2, 2, 2, 2, 2),
#  (276.0, 'bishoptrevor', 'Michael Thompson', 2, 2, 2, 2, 2),
#  (281.0, 'brittneylam', 'Randall Vaughan', 2, 2, 2, 2, 2),
#  (290.0, 'christopherkerr', 'David Hill', 2, 2, 2, 2, 2),
#  (306.0, 'cknapp', 'Kristin Luna', 2, 2, 2, 2, 2),
#  (313.0, 'scott99', 'Rebecca Dougherty', 2, 2, 2, 2, 2),
#  (328.0, 'tammy97', 'Tammy Mack', 2, 2, 2, 2, 2),
#  (334.0, 'cindyhowell', 'Andrea Oliver', 2, 2, 2, 2, 2),
#  (342.0, 'lsmith', 'Darlene Marshall', 2, 2, 2, 2, 2),
#  (349.0, 'ijohnson', 'Ronald Jones', 2, 2, 2, 2, 2),
#  (356.0, 'briggsbradley', 'Cynthia Brown', 2, 2, 2, 2, 2),
#  (360.0, 'riveracolleen', 'Andrew Green', 2, 2, 2, 2, 2),
#  (367.0, 'suzanne57', 'Melissa Turner', 2, 2, 2, 2, 2),
#  (368.0, 'tonyajones', 'Jose Moore', 2, 2, 2, 2, 2),
#  (376.0, 'levi67', 'Jody Benjamin', 2, 2, 2, 2, 2),
#  (382.0, 'lscott', 'John Patel', 2, 2, 2, 2, 2),
#  (401.0, 'bjimenez', 'Traci Mejia', 2, 2, 2, 2, 2),
#  (412.0, 'gregorychristine', 'Ross Meadows', 2, 2, 2, 2, 2),
#  (415.0, 'yherrera', 'Kelly Shepherd', 2, 2, 2, 2, 2),
#  (434.0, 'ksmith', 'Robert Brown', 2, 2, 2, 2, 2),
#  (452.0, 'jacqueline60', 'Corey Burton', 2, 2, 2, 2, 2),
#  (454.0, 'lpineda', 'Dana Buckley', 2, 2, 2, 2, 2),
#  (457.0, 'johnsonantonio', 'Andrew Robertson', 2, 2, 2, 2, 2),
#  (469.0, 'iallen', 'Samantha Young', 2, 2, 2, 2, 2),
#  (478.0, 'grussell', 'Phyllis Anderson', 2, 2, 2, 2, 2),
#  (490.0, 'robert62', 'Barbara Brown', 2, 2, 2, 2, 2),
#  (494.0, 'athompson', 'Julie Hudson', 2, 2, 2, 2, 2),
#  (496.0, 'nwagner', 'Brianna Miller', 2, 2, 2, 2, 2),
#  (3.0, 'charlesjohnson', 'Maria Mckay', 1, 1, 1, 1, 1),
#  (13.0, 'aaronbutler', 'George Holt', 1, 1, 1, 1, 1),
#  (24.0, 'christinastevens', 'Ryan Martin', 1, 1, 1, 1, 1),
#  (34.0, 'rogerskaren', 'Sara Norman', 1, 1, 1, 1, 1),
#  (37.0, 'burkelogan', 'Heather Williams', 1, 1, 1, 1, 1),
#  (41.0, 'meyersnathan', 'John Martinez', 1, 1, 1, 1, 1),
#  (42.0, 'twagner', 'Amanda Johnston', 1, 1, 1, 1, 1),
#  (44.0, 'mcmahonanna', 'Morgan Jackson', 1, 1, 1, 1, 1),
#  (45.0, 'robertvaughn', 'James Cook', 1, 1, 1, 1, 1),
#  (47.0, 'hamiltonkarla', 'Travis Gallegos', 1, 1, 1, 1, 1),
#  (49.0, 'francoalexandra', 'Colleen Riley', 1, 1, 1, 1, 1),
#  (51.0, 'davidjones', 'Miguel Bailey', 1, 1, 1, 1, 1),
#  (54.0, 'christopher17', 'Adriana Howard', 1, 1, 1, 1, 1),
#  (58.0, 'melissaclayton', 'John Adams', 1, 1, 1, 1, 1),
#  (70.0, 'rebeccagarcia', 'Allison Velasquez', 1, 1, 1, 1, 1),
#  (72.0, 'cindyhiggins', 'Brooke Gomez', 1, 1, 1, 1, 1),
#  (74.0, 'woodsdonald', 'Taylor Brown', 1, 1, 1, 1, 1),
#  (99.0, 'brownkristina', 'Cody Mclean', 1, 1, 1, 1, 1),
#  (100.0, 'rmartin', 'Jessica Carpenter', 1, 1, 1, 1, 1),
#  (107.0, 'zmason', 'Margaret Wallace', 1, 1, 1, 1, 1),
#  (109.0, 'lauriewheeler', 'Jack Martin', 1, 1, 1, 1, 1),
#  (111.0, 'sharon53', 'Willie Nash', 1, 1, 1, 1, 1),
#  (122.0, 'jason12', 'Elizabeth Hill', 1, 1, 1, 1, 1),
#  (133.0, 'mathewwatts', 'Patrick Khan', 1, 1, 1, 1, 1),
#  (141.0, 'osbornegregory', 'Debra Mcfarland', 1, 1, 1, 1, 1),
#  (143.0, 'martinezjesse', 'Charles Hardin', 1, 1, 1, 1, 1),
#  (155.0, 'erica79', 'Raymond Paul', 1, 1, 1, 1, 1),
#  (177.0, 'acostaalexis', 'Katelyn Johnson', 1, 1, 1, 1, 1),
#  (181.0, 'lyoung', 'Margaret Thomas', 1, 1, 1, 1, 1),
#  (187.0, 'torresbelinda', 'Kenneth Gibbs', 1, 1, 1, 1, 1),
#  (198.0, 'zrice', 'Sharon Kim', 1, 1, 1, 1, 1),
#  (199.0, 'amber22', 'David Fields', 1, 1, 1, 1, 1),
#  (213.0, 'qcarter', 'Brian Rubio', 1, 1, 1, 1, 1),
#  (220.0, 'crystal20', 'Julie Porter', 1, 1, 1, 1, 1),
#  (235.0, 'alexandermiller', 'Tamara Montoya', 1, 1, 1, 1, 1),
#  (236.0, 'angeladuke', 'Brandy Vazquez', 1, 1, 1, 1, 1),
#  (248.0, 'linda45', 'Monica Harper', 1, 1, 1, 1, 1),
#  (249.0, 'ojones', 'Dana George', 1, 1, 1, 1, 1),
#  (251.0, 'shafferjason', 'Stephanie Mcfarland', 1, 1, 1, 1, 1),
#  (259.0, 'dhernandez', 'Christopher Villanueva', 1, 1, 1, 1, 1),
#  (267.0, 'awright', 'Anna Banks', 1, 1, 1, 1, 1),
#  (273.0, 'alice42', 'Ross Underwood', 1, 1, 1, 1, 1),
#  (277.0, 'nicole35', 'Sarah Doyle', 1, 1, 1, 1, 1),
#  (286.0, 'danielwallace', 'Kathryn King', 1, 1, 1, 1, 1),
#  (299.0, 'kmerritt', 'Paul Byrd', 1, 1, 1, 1, 1),
#  (317.0, 'cmiller', 'Sarah Henderson', 1, 1, 1, 1, 1),
#  (323.0, 'martinezjennifer', 'Rachel Willis', 1, 1, 1, 1, 1),
#  (326.0, 'jordanphillip', 'Erin Harrison', 1, 1, 1, 1, 1),
#  (329.0, 'nancyjensen', 'Kayla Franklin', 1, 1, 1, 1, 1),
#  (341.0, 'kenneth88', 'Miguel Conrad', 1, 1, 1, 1, 1),
#  (343.0, 'katherinesmith', 'Mark Jones', 1, 1, 1, 1, 1),
#  (359.0, 'samantha93', 'Joseph Cline', 1, 1, 1, 1, 1),
#  (362.0, 'jacksonkelly', 'Jerry Hoover', 1, 1, 1, 1, 1),
#  (363.0, 'evansimmons', 'Brandon Mosley', 1, 1, 1, 1, 1),
#  (365.0, 'russell80', 'Austin Hayes', 1, 1, 1, 1, 1),
#  (385.0, 'melissaholloway', 'Michael Pham', 1, 1, 1, 1, 1),
#  (388.0, 'cindywilliams', 'Lisa Grant', 1, 1, 1, 1, 1),
#  (389.0, 'christina53', 'Patrick Coleman', 1, 1, 1, 1, 1),
#  (394.0, 'theodorebarnes', 'Kelly Jackson', 1, 1, 1, 1, 1),
#  (399.0, 'hannah50', 'Christopher Rodriguez', 1, 1, 1, 1, 1),
#  (402.0, 'warren27', 'Kathryn Perez', 1, 1, 1, 1, 1),
#  (406.0, 'dylanharper', 'Timothy Mays', 1, 1, 1, 1, 1),
#  (419.0, 'colleen10', 'Troy Fitzgerald', 1, 1, 1, 1, 1),
#  (425.0, 'dwong', 'Holly Larson', 1, 1, 1, 1, 1),
#  (426.0, 'lwilliams', 'Savannah Noble', 1, 1, 1, 1, 1),
#  (432.0, 'melaniecameron', 'Madison Miller', 1, 1, 1, 1, 1),
#  (442.0, 'hcarney', 'Jeremy Lowery', 1, 1, 1, 1, 1),
#  (455.0, 'troy41', 'Tammy Sanders', 1, 1, 1, 1, 1),
#  (456.0, 'fclark', 'Melinda Huynh', 1, 1, 1, 1, 1),
#  (458.0, 'galvanbarbara', 'Mia Welch', 1, 1, 1, 1, 1),
#  (464.0, 'harrismisty', 'Erin Rodriguez', 1, 1, 1, 1, 1),
#  (474.0, 'fryan', 'Thomas Steele', 1, 1, 1, 1, 1),
#  (477.0, 'leestein', 'Jeffrey Williams', 1, 1, 1, 1, 1),
#  (479.0, 'jessica49', 'Roger Tanner', 1, 1, 1, 1, 1),
#  (483.0, 'bryandavidson', 'Adam Weiss', 1, 1, 1, 1, 1),
#  (489.0, 'nguyenrandy', 'Jillian Duran', 1, 1, 1, 1, 1),
#  (497.0, 'amanda32', 'Joshua Harrison', 1, 1, 1, 1, 1),
#  (499.0, 'blakekyle', 'Alexis Fletcher', 1, 1, 1, 1, 1)]
