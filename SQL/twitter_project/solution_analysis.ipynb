# %%
# %load_ext sql

# %%
from dotenv import load_dotenv
import os

load_dotenv()

user = os.getenv("MYSQL_USER")
password = os.getenv("MYSQL_PASSWORD")
host = os.getenv("MYSQL_HOST")
port = os.getenv("MYSQL_PORT")
db = os.getenv("MYSQL_DB")

connection_str = f"mysql+pymysql://{user}:{password}@{host}:{port}/{db}"

# %sql $connection_str

# %% [markdown]
# ## 1. Scenario Q1
# ### Analysis of most active users
# You are a Data Analyst at Twitter and are tasked with analysing user engagement. You
# need to find out which users have the highest engagement on the platform. For this
# analysis, consider a user to be engaged if they have sent messages, liked tweets,
# been mentioned, received notifications, and retweeted tweets

# %%
# %%sql
# SELECT
#     u.UserID, u.Username, u.FullName,
#     COUNT(m.SenderID) AS total_messages_sent,
#     COUNT(l.LikeID) AS total_liked_tweets,
#     COUNT(men.MentionedUserID) AS total_mentions,
#     COUNT(n.NotificationID) AS total_notifications_received,
#     COUNT(r.RetweetID) AS total_retweets,
#     (
#         COUNT(m.SenderID) +
#         COUNT(l.LikeID) +
#         COUNT(men.MentionedUserID) +
#         COUNT(n.NotificationID) +
#         COUNT(r.RetweetID)
#     ) AS total_engagements
# FROM
#     users u
# INNER JOIN directmessages m
# ON u.UserID = m.SenderID
# INNER JOIN likes l
# ON u.UserID = l.LikeID
# INNER JOIN mentions men
# ON u.UserID = men.MentionedUserID
# INNER JOIN notifications n
# ON u.UserID = n.NotificationID
# INNER JOIN retweets r
# ON u.UserID = r.RetweetID
# GROUP BY
#     (u.UserID)
# ORDER BY
#     total_messages_sent DESC, total_liked_tweets DESC,
#     total_mentions DESC, total_notifications_received DESC,
#     total_retweets DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 5 rows affected.
# [(397.0, 'joseph47', 'Douglas Nichols', 15, 15, 15, 15, 15, 75),
#  (258.0, 'christopher66', 'James Gomez', 9, 9, 9, 9, 9, 45),
#  (461.0, 'gkelly', 'Jeffrey Meadows', 8, 8, 8, 8, 8, 40),
#  (268.0, 'rachelflores', 'Michelle Myers MD', 8, 8, 8, 8, 8, 40),
#  (300.0, 'michael20', 'Penny Curtis', 8, 8, 8, 8, 8, 40)]

# %% [markdown]
# ## 2. Scenario Q2
# ### Find Users with Most Followers
# Retrieve the top 5 users with the most followers, including their UserID, Username,
# FullName, and FollowerCount

# %%
# %%sql
#
# SELECT
#     u.UserID, u.Username, u.FullName,
#     COUNT(f.FollowedUserID) AS FollowerCount
# FROM
#     users u
# INNER JOIN followers f
# ON u.UserID = f.FollowerUserID
# GROUP BY
#     u.UserID
# ORDER BY
#     FollowerCount DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 5 rows affected.
# [(363.0, 'evansimmons', 'Brandon Mosley', 4),
#  (153.0, 'kanerussell', 'Kristen Wade', 4),
#  (335.0, 'trivas', 'Stacey Brown MD', 4),
#  (95.0, 'ryanadams', 'Christopher Williams', 4),
#  (456.0, 'fclark', 'Melinda Huynh', 4)]

# %% [markdown]
# ## 3. Scenario Q3
# ### Identify Users with Unread Notifications
# Identify all users who have unread notifications. Display their UserID, Username,
# FullName, and the count of UnreadNotifications.

# %%
# %%sql
#
# SELECT
#     u.UserID, u.Username, u.FullName,
#     COUNT(n.notificationID) AS total_unread_notifications
# FROM
#     users u
# INNER JOIN notifications n
# ON u.UserID = n.UserID
# WHERE
#     n.IsRead = 0
# GROUP BY
#     u.UserID
# ORDER BY
#     total_unread_notifications DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 189 rows affected.
# [(80.0, 'tayloralexis', 'Lisa Davis', 3),
#  (353.0, 'hickmancarrie', 'Tina Lopez', 3),
#  (369.0, 'rlynch', 'Tyler Wilkerson', 3),
#  (8.0, 'katherinerogers', 'Stacy Chan', 3),
#  (317.0, 'cmiller', 'Sarah Henderson', 3),
#  (426.0, 'lwilliams', 'Savannah Noble', 3),
#  (466.0, 'tmccarty', 'Laura Nguyen', 3),
#  (424.0, 'elopez', 'Duane Everett', 3),
#  (40.0, 'thomasjeffery', 'Bradley Berg', 2),
#  (408.0, 'wdavidson', 'Amber Newman', 2),
#  (292.0, 'browncynthia', 'Charles Taylor', 2),
#  (202.0, 'stewartmaria', 'Chelsea Rogers', 2),
#  (7.0, 'jasmineberry', 'Mark James', 2),
#  (338.0, 'donnapotter', 'Mrs. Holly Barnes', 2),
#  (173.0, 'vicki07', 'Donald Lara', 2),
#  (249.0, 'ojones', 'Dana George', 2),
#  (272.0, 'steven35', 'Samuel Tucker', 2),
#  (63.0, 'laura32', 'Jennifer Liu', 2),
#  (82.0, 'christielarson', 'Deanna Farmer', 2),
#  (301.0, 'nathangriffin', 'Amber Jacobs', 2),
#  (417.0, 'heather32', 'Lorraine Webb', 2),
#  (117.0, 'mcdowellandrew', 'Donald Collier', 2),
#  (79.0, 'parkerjamie', 'Rhonda Phillips', 2),
#  (285.0, 'mary06', 'Shannon Farrell', 2),
#  (33.0, 'tamara12', 'Courtney Snyder', 2),
#  (500.0, 'connieberry', 'Teresa Jackson', 2),
#  (458.0, 'galvanbarbara', 'Mia Welch', 2),
#  (223.0, 'margaret99', 'George Curry', 2),
#  (3.0, 'charlesjohnson', 'Maria Mckay', 2),
#  (336.0, 'mcdanielraymond', 'Geoffrey Spencer', 2),
#  (48.0, 'smithalexis', 'Christina Powell', 2),
#  (273.0, 'alice42', 'Ross Underwood', 2),
#  (416.0, 'christopherpatterson', 'Ruben Harris', 2),
#  (118.0, 'janderson', 'Vanessa Benjamin', 2),
#  (46.0, 'sean36', 'Charles Robinson', 2),
#  (389.0, 'christina53', 'Patrick Coleman', 2),
#  (352.0, 'jillian46', 'Amy Lee', 2),
#  (229.0, 'taylorlawrence', 'Linda Bryant', 2),
#  (331.0, 'agreen', 'Olivia Garner', 2),
#  (412.0, 'gregorychristine', 'Ross Meadows', 2),
#  (379.0, 'normanstephanie', 'Randy Ross', 2),
#  (205.0, 'griffinjames', 'Cody Chavez', 2),
#  (31.0, 'cgardner', 'Jessica Hansen', 2),
#  (16.0, 'david76', 'Brandi Quinn', 2),
#  (138.0, 'kwilliams', 'Julie Garcia', 2),
#  (119.0, 'michaelamartinez', 'Kelly Rich', 1),
#  (84.0, 'adamblake', 'Bryan Rogers', 1),
#  (351.0, 'gregorybrendan', 'Jessica James', 1),
#  (387.0, 'conwayalex', 'Melvin Smith', 1),
#  (34.0, 'rogerskaren', 'Sara Norman', 1),
#  (160.0, 'ohernandez', 'Chris Little MD', 1),
#  (169.0, 'tknight', 'Scott Ferguson', 1),
#  (422.0, 'floydcindy', 'Ashley Juarez', 1),
#  (441.0, 'chad61', 'Mark Robbins', 1),
#  (65.0, 'wfaulkner', 'Teresa Shaw', 1),
#  (78.0, 'yflores', 'Denise Case', 1),
#  (372.0, 'nortiz', 'James Hernandez', 1),
#  (463.0, 'rileyvalerie', 'Linda Lewis', 1),
#  (97.0, 'xtorres', 'Jillian Lane', 1),
#  (149.0, 'brandi33', 'Steven Vazquez', 1),
#  (298.0, 'xwilliams', 'Nicholas Garner', 1),
#  (384.0, 'warnerchristopher', 'Brandon Fox', 1),
#  (373.0, 'annagonzalez', 'Caitlin Johnson', 1),
#  (180.0, 'powellcarrie', 'Richard Duran', 1),
#  (452.0, 'jacqueline60', 'Corey Burton', 1),
#  (435.0, 'campbelldebbie', 'Vanessa Morrison', 1),
#  (406.0, 'dylanharper', 'Timothy Mays', 1),
#  (220.0, 'crystal20', 'Julie Porter', 1),
#  (10.0, 'davisgina', 'Teresa Carr', 1),
#  (323.0, 'martinezjennifer', 'Rachel Willis', 1),
#  (434.0, 'ksmith', 'Robert Brown', 1),
#  (104.0, 'scott82', 'Anthony Burns', 1),
#  (354.0, 'emilymiles', 'Robert Brown', 1),
#  (214.0, 'michael59', 'Andrew Glass', 1),
#  (238.0, 'davidallen', 'Lindsay Mendez', 1),
#  (197.0, 'jennifer82', 'Paul Kemp', 1),
#  (474.0, 'fryan', 'Thomas Steele', 1),
#  (25.0, 'andersonrichard', 'Pamela Johnson', 1),
#  (419.0, 'colleen10', 'Troy Fitzgerald', 1),
#  (306.0, 'cknapp', 'Kristin Luna', 1),
#  (400.0, 'kfreeman', 'Mrs. Ashley Rodriguez', 1),
#  (228.0, 'youngwilliam', 'Anthony James', 1),
#  (107.0, 'zmason', 'Margaret Wallace', 1),
#  (433.0, 'dwhite', 'Jennifer Larson', 1),
#  (311.0, 'millerrichard', 'Suzanne Watson', 1),
#  (305.0, 'jason06', 'Dennis Davis', 1),
#  (11.0, 'tashley', 'Nicole Davis', 1),
#  (102.0, 'turnerjames', 'Michael Bradshaw', 1),
#  (37.0, 'burkelogan', 'Heather Williams', 1),
#  (200.0, 'frankdaniel', 'Robert Moreno', 1),
#  (194.0, 'mckeedavid', 'Marcus Brown', 1),
#  (9.0, 'jordansusan', 'William Edwards', 1),
#  (86.0, 'owensshannon', 'Jamie Smith', 1),
#  (360.0, 'riveracolleen', 'Andrew Green', 1),
#  (345.0, 'brandonjackson', 'Alexander Rollins', 1),
#  (438.0, 'fmitchell', 'Michael Walker', 1),
#  (17.0, 'meghan35', 'Megan Perez', 1),
#  (213.0, 'qcarter', 'Brian Rubio', 1),
#  (246.0, 'dbaker', 'Ryan Jackson', 1),
#  (490.0, 'robert62', 'Barbara Brown', 1),
#  (374.0, 'rolsen', 'Kimberly Williams', 1),
#  (154.0, 'williambeck', 'Brittany Camacho', 1),
#  (339.0, 'kimberly29', 'Cody Blankenship', 1),
#  (170.0, 'milesamanda', 'Steven Ray', 1),
#  (454.0, 'lpineda', 'Dana Buckley', 1),
#  (313.0, 'scott99', 'Rebecca Dougherty', 1),
#  (132.0, 'qparks', 'Barbara Rogers', 1),
#  (47.0, 'hamiltonkarla', 'Travis Gallegos', 1),
#  (444.0, 'jhall', 'Allison Harris', 1),
#  (460.0, 'andrewsanchez', 'Brian Garza', 1),
#  (425.0, 'dwong', 'Holly Larson', 1),
#  (394.0, 'theodorebarnes', 'Kelly Jackson', 1),
#  (281.0, 'brittneylam', 'Randall Vaughan', 1),
#  (239.0, 'susantaylor', 'Rachel Chan', 1),
#  (340.0, 'fisherjason', 'Amber Alexander', 1),
#  (159.0, 'wcurry', 'Hector White', 1),
#  (356.0, 'briggsbradley', 'Cynthia Brown', 1),
#  (152.0, 'matthew81', 'Brett Morales', 1),
#  (106.0, 'mmonroe', 'Gregory Jordan', 1),
#  (192.0, 'woodalicia', 'Eric Garcia', 1),
#  (496.0, 'nwagner', 'Brianna Miller', 1),
#  (310.0, 'morrisonmelissa', 'Judy Wilson', 1),
#  (282.0, 'llee', 'Kimberly Burton', 1),
#  (410.0, 'robert16', 'Travis Ballard', 1),
#  (217.0, 'xporter', 'Nicole Ryan', 1),
#  (144.0, 'nicole76', 'Danielle Ingram', 1),
#  (380.0, 'austin82', 'Thomas Hunter', 1),
#  (67.0, 'smithlaura', 'Adam Phillips', 1),
#  (477.0, 'leestein', 'Jeffrey Williams', 1),
#  (224.0, 'kristiperry', 'Alyssa Petersen', 1),
#  (158.0, 'erika23', 'Kristine Wheeler', 1),
#  (440.0, 'collinsmatthew', 'Rebecca Powell', 1),
#  (77.0, 'joshuabrady', 'Whitney Maddox', 1),
#  (392.0, 'katrinareed', 'Kimberly Chase', 1),
#  (261.0, 'nicholaschase', 'Veronica Hopkins', 1),
#  (55.0, 'shermanmatthew', 'Travis Walker', 1),
#  (291.0, 'garyowens', 'Carol Beck', 1),
#  (235.0, 'alexandermiller', 'Tamara Montoya', 1),
#  (471.0, 'bridget38', 'Robert Cook', 1),
#  (367.0, 'suzanne57', 'Melissa Turner', 1),
#  (398.0, 'brianaryan', 'Jon Russell', 1),
#  (19.0, 'trevorstewart', 'Brandy Hall', 1),
#  (92.0, 'maldonadoanthony', 'Gregory Cobb', 1),
#  (207.0, 'melindahouston', 'James Weaver', 1),
#  (437.0, 'lauramorgan', 'Aimee Hall', 1),
#  (36.0, 'kyleholmes', 'Kerri Fernandez', 1),
#  (204.0, 'tiffany34', 'Derrick Henderson MD', 1),
#  (381.0, 'jamesrichards', 'Mr. Larry Oliver', 1),
#  (495.0, 'jordan59', 'Hannah Rice', 1),
#  (69.0, 'kimberlydennis', 'Heather Small', 1),
#  (203.0, 'murraymichael', 'Mary Bullock', 1),
#  (248.0, 'linda45', 'Monica Harper', 1),
#  (304.0, 'philip33', 'Robert Hudson', 1),
#  (76.0, 'orodriguez', 'David Meyer', 1),
#  (234.0, 'gonzaleschristine', 'Tracy Vasquez', 1),
#  (449.0, 'dennis52', 'Beth Preston', 1),
#  (324.0, 'stephanie82', 'Tasha Campbell', 1),
#  (486.0, 'carljohnson', 'Nathan Cortez', 1),
#  (262.0, 'floresangela', 'Amber Lee', 1),
#  (300.0, 'michael20', 'Penny Curtis', 1),
#  (66.0, 'jeanshaw', 'Jennifer Garrett', 1),
#  (376.0, 'levi67', 'Jody Benjamin', 1),
#  (29.0, 'edwardhooper', 'David Franco', 1),
#  (210.0, 'burnsphillip', 'Ethan Reyes', 1),
#  (199.0, 'amber22', 'David Fields', 1),
#  (344.0, 'donald92', 'Natasha Wilson', 1),
#  (289.0, 'billparker', 'Joshua Wagner', 1),
#  (230.0, 'andreclark', 'Austin Johnson', 1),
#  (330.0, 'charleslane', 'John Ortega', 1),
#  (211.0, 'brian24', 'Savannah Shaffer', 1),
#  (328.0, 'tammy97', 'Tammy Mack', 1),
#  (208.0, 'urobinson', 'April Sanchez', 1),
#  (265.0, 'msmith', 'Brenda Fox', 1),
#  (166.0, 'dylanlopez', 'James Pennington', 1),
#  (446.0, 'tanyamurphy', 'Denise Gibson', 1),
#  (450.0, 'afoster', 'Allison Baker', 1),
#  (326.0, 'jordanphillip', 'Erin Harrison', 1),
#  (286.0, 'danielwallace', 'Kathryn King', 1),
#  (312.0, 'klinepenny', 'Mrs. Amber Santana', 1),
#  (109.0, 'lauriewheeler', 'Jack Martin', 1),
#  (110.0, 'victorburns', 'Terry Miranda', 1),
#  (177.0, 'acostaalexis', 'Katelyn Johnson', 1),
#  (6.0, 'fmckee', 'Michael Tran', 1),
#  (71.0, 'uharrison', 'Erika Reyes', 1),
#  (494.0, 'athompson', 'Julie Hudson', 1),
#  (370.0, 'wbrown', 'Angela Carroll', 1),
#  (461.0, 'gkelly', 'Jeffrey Meadows', 1),
#  (361.0, 'gutierrezryan', 'Jennifer Fox', 1),
#  (240.0, 'aprilmccoy', 'Kathleen Jenkins', 1)]

# %% [markdown]
# ## 4. Scenario Q4
# ### Identify Most Liked Tweets
# Find the top 5 tweets that have received the most likes, including their TweetID and
# LikeCount. Also, retrieve the UserID, Username, and FullName of the users who
# posted these tweets

# %%
# %%sql
#
# SELECT
#     u.UserID, u.Username, u.FullName,
#     t.TweetID, t.TweetText,
#     COUNT(l.LikeID) AS LikeCount
# FROM users u
# INNER JOIN tweets t
# ON u.UserID = t.UserID
# INNER JOIN likes l
# ON t.TweetID = l.TweetID
# GROUP BY
#     u.UserID, t.TweetID
# ORDER BY
#     LikeCount DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 5 rows affected.
# [(305.0, 'jason06', 'Dennis Davis', 245.0, 'Medical executive great fear much term rate establish. Soon air view Mrs attack room feeling involve. Decision character theory memory yes.\nTough win walk really discuss.\nChoose nor exactly paper. House student play win popular member need floor.', 5),
#  (100.0, 'rmartin', 'Jessica Carpenter', 73.0, 'Everyone no garden evidence contain. Safe up include skin ahead cell cultural.\nTonight anything through skin dog near. Morning staff into keep third responsibility. Campaign heart radio others much.\nSeek choose yet grow summer so certainly. Campaign agent form enough black.', 4),
#  (372.0, 'nortiz', 'James Hernandez', 266.0, 'New improve relationship all participant herself popular. Detail only strong color. Power and life hour her especially couple program.\nClaim product edge. Soon according generation we sit.\nSomeone cell indicate because whose politics. Alone film successful fine prove these.', 4),
#  (44.0, 'mcmahonanna', 'Morgan Jackson', 217.0, 'Republican white stop catch senior.\nWhat perform more budget rest produce. Back shake government card. Me must strong help health rate. Look name season material nothing.\nResult never never spring still size pass human. Forward nature sing purpose.', 4),
#  (491.0, 'johnsonmonica', 'Cheyenne Aguirre', 180.0, 'Traditional spring operation community could our. Real approach many treatment.\nHeart budget program particular half send operation window. Then phone character shake.', 4)]

# %% [markdown]
# ## 5. Scenario Q5
# ### Determine User Growth Over Time
# Analyse the growth of users joining the platform over time. Retrieve the count of users
# who joined each month and year

# %%
# %%sql
# SELECT
#     MONTH(JoinDate) AS month_join,
#     YEAR(JoinDate) AS year_join,
#     COUNT(UserID) AS number_of_users
# FROM
#     users
# GROUP BY
#     year_join, month_join
# ORDER BY
#     year_join ASC, month_join ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 61 rows affected.
# [(9, 2018, 2),
#  (10, 2018, 7),
#  (11, 2018, 9),
#  (12, 2018, 7),
#  (1, 2019, 12),
#  (2, 2019, 4),
#  (3, 2019, 14),
#  (4, 2019, 11),
#  (5, 2019, 6),
#  (6, 2019, 5),
#  (7, 2019, 8),
#  (8, 2019, 6),
#  (9, 2019, 4),
#  (10, 2019, 7),
#  (11, 2019, 10),
#  (12, 2019, 8),
#  (1, 2020, 6),
#  (2, 2020, 9),
#  (3, 2020, 9),
#  (4, 2020, 9),
#  (5, 2020, 5),
#  (6, 2020, 8),
#  (7, 2020, 9),
#  (8, 2020, 13),
#  (9, 2020, 10),
#  (10, 2020, 14),
#  (11, 2020, 10),
#  (12, 2020, 10),
#  (1, 2021, 7),
#  (2, 2021, 9),
#  (3, 2021, 7),
#  (4, 2021, 2),
#  (5, 2021, 10),
#  (6, 2021, 14),
#  (7, 2021, 11),
#  (8, 2021, 9),
#  (9, 2021, 9),
#  (10, 2021, 7),
#  (11, 2021, 10),
#  (12, 2021, 7),
#  (1, 2022, 8),
#  (2, 2022, 7),
#  (3, 2022, 6),
#  (4, 2022, 8),
#  (5, 2022, 10),
#  (6, 2022, 3),
#  (7, 2022, 1),
#  (8, 2022, 16),
#  (9, 2022, 5),
#  (10, 2022, 13),
#  (11, 2022, 7),
#  (12, 2022, 3),
#  (1, 2023, 10),
#  (2, 2023, 4),
#  (3, 2023, 12),
#  (4, 2023, 13),
#  (5, 2023, 14),
#  (6, 2023, 8),
#  (7, 2023, 5),
#  (8, 2023, 5),
#  (9, 2023, 8)]

# %% [markdown]
# ## 6. Scenario Q6
# ### Analyse Notification Engagement
# Evaluate how users are engaging with notifications. Find the number of notifications
# sent to users, the number of notifications read, and the read rate (percentage of
# notifications read) for each NotificationType.

# %%
# %%sql
# SELECT
#     NotificationType,
#     COUNT(NotificationID) AS total_notifications_sent,
#     SUM(CASE WHEN IsRead = 1 THEN 1 ELSE 0 END) AS read_notifications,
#     CONCAT(ROUND((SUM(CASE WHEN IsRead = 1 THEN 1 ELSE 0 END)/COUNT(NotificationID)) * 100, 2), '%') AS read_percentage
# FROM
#     notifications
# GROUP BY
#     NotificationType
# ORDER BY
#     total_notifications_sent DESC, read_notifications DESC, read_percentage DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 3 rows affected.
# [('Follow', 176, Decimal('85'), '48.30%'),
#  ('Like', 167, Decimal('91'), '54.49%'),
#  ('Comment', 157, Decimal('82'), '52.23%')]

# %% [markdown]
# ## 7. Scenario Q7
# ### Identify Influential Users and Their Impact on User Engagement
# Twitter is interested in identifying influential users on its platform to understand their
# impact on user engagement. Influential users are characterized by a high number of
# followers and frequent interactions (e.g., messages, likes, mentions, retweets). By
# identifying these users, Twitter can analyze their content, engagement patterns, and
# potentially leverage their influence for marketing and promotional activities.
# Specific Tasks:
# #### a. Identify Influential Users: Find the top 5 users with the most followers and list their
# UserID, Username, FullName, and the number of followers.
# #### b. Analyze User Engagement: For each of the identified influential users, calculate
# their engagement on the platform by counting the number of messages sent,
# tweets liked, mentions received, notifications received, and tweets retweeted.

# %%
# %%sql
#
# WITH TopFollowers AS (
#     SELECT
#         f.FollowedUserID AS UserID,
#         COUNT(f.FollowerID) AS NumberOfFollowers
#     FROM followers f
#     GROUP BY f.FollowedUserID
#     ORDER BY COUNT(f.FollowerID) DESC
#     LIMIT 5
# )
# SELECT
#     u.UserID,
#     u.Username,
#     u.FullName,
#     tf.NumberOfFollowers,
#     COUNT(DISTINCT m.MessageID) AS NumberOfMessagesSent,
#     COUNT(DISTINCT l.LikeID) AS TweetsLiked,
#     COUNT(DISTINCT men.MentionID) AS MentionsReceived,
#     COUNT(DISTINCT n.NotificationID) AS NotificationsReceived,
#     COUNT(DISTINCT r.RetweetID) AS TweetsRetweeted
# FROM TopFollowers tf
# JOIN users u ON u.UserID = tf.UserID
# LEFT JOIN directmessages m ON u.UserID = m.SenderID
# LEFT JOIN likes l ON u.UserID = l.UserID
# LEFT JOIN mentions men ON u.UserID = men.UserID
# LEFT JOIN notifications n ON u.UserID = n.UserID
# LEFT JOIN retweets r ON u.UserID = r.UserID
# GROUP BY u.UserID, u.Username, u.FullName, tf.NumberOfFollowers
# ORDER BY tf.NumberOfFollowers DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 5 rows affected.
# [(220.0, 'crystal20', 'Julie Porter', 5, 1, 1, 0, 1, 5),
#  (2.0, 'joseph66', 'Sydney Taylor', 4, 0, 0, 1, 0, 2),
#  (27.0, 'vpierce', 'Anne Lopez', 4, 2, 0, 1, 0, 0),
#  (31.0, 'cgardner', 'Jessica Hansen', 4, 3, 3, 2, 3, 0),
#  (59.0, 'laurasparks', 'Jennifer Smith', 4, 0, 0, 1, 0, 1)]

# %% [markdown]
# ## 8. Scenario Q8
# ### Track User Retention and Platform Engagement Over Time
# Twitter aims to enhance user experience and engagement on its platform to ensure
# user retention. The company wants to analyse the activities of users who joined the
# platform within the last year and assess their engagement levels to identify patterns
# and areas for improvement.
# Specific Tasks:
# ### a. User Retention Analysis: Determine the number of users who joined in the last year
# and are still active on the platform, based on their engagement in various activities
# (messages, likes, mentions, retweets) in the last month.
# ### b. Engagement Analysis: For the retained users, analyse the frequency of their
# engagement in different activities on the platform.

# %%
# %%sql
# # a. User Retention Analysis: Determine the number of users who joined in the last year
#
# CREATE VIEW RecentActiveUsers AS (
#     SELECT
#         u.UserID, u.Username, u.FullName, u.JoinDate,
#         COUNT(m.MessageID) AS MessagesSentLastMonth
#     FROM
#         users u
#     LEFT JOIN
#         directmessages m
#     ON u.UserID = m.SenderID
#     WHERE
#         u.JoinDate >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) AND
#         (m.`Timestamp` >= DATE_SUB(CURDATE(), INTERVAL 1 MONTH))
#     GROUP BY
#         u.UserID, u.Username, u.FullName
#     ORDER BY
#         MessagesSentLastMonth DESC
# )
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 0 rows affected.
# []

# %%
# %%sql
# # b. Engagement analysis:
#
# SELECT
#     rau.UserID, rau.Username, rau.FullName, rau.JoinDate, rau.MessagesSentLastMonth,
#     COUNT(l.UserID) AS likeMade,
#     COUNT(men.MentionID) AS MentionsMade,
#     COUNT(n.NotificationID) AS NotificationMade,
#     COUNT(r.RetweetID) AS RetweetMade,
#     COUNT(t.TweetID) AS TweetMade
# FROM
#     RecentActiveUsers rau
# LEFT JOIN likes l
# ON rau.UserID = l.UserID
# LEFT JOIN mentions men
# ON rau.UserID = men.MentionedUserID
# LEFT JOIN notifications n
# ON rau.UserID = n.UserID
# LEFT JOIN retweets r
# ON rau.UserID = r.UserID
# LEFT JOIN tweets t
# ON rau.UserID = t.UserID
# GROUP BY
#     rau.UserID, rau.Username, rau.FullName
# ORDER BY
#     rau.JoinDate ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 0 rows affected.
# []

# %% [markdown]
# ## 9. Scenario Q9
# ### Analyse the Most Common Type of User Notifications
# Twitter wants to understand which type of notifications users receive most frequently
# to optimize user engagement and notification relevance. By analysing the most
# common notification types, Twitter can tailor its notification system to enhance user
# experience.
# The task is to Identify the most common notification type received by users. Display
# the NotificationType and the count of notifications for each type, ordered by the count
# in descending order.

# %%
# %%sql
# SELECT
#     notificationtype,
#     COUNT(DISTINCT notificationID) AS NumberOfNotification
# FROM
#     notifications
# GROUP BY
#     notificationtype
# ORDER BY
#     NumberOfNotification DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 3 rows affected.
# [('Follow', 176), ('Like', 167), ('Comment', 157)]

# %% [markdown]
# ## 10.Scenario Q10
# ### Discover Users with High Engagement but Low Follower Count
# Twitter is interested in identifying users who are highly engaged on the platform but
# have relatively few followers. Recognizing and promoting such users could potentially
# diversify the content on the platform and improve overall user engagement.
# Specific Task:
# Find the top 5 users who have sent the most messages but have fewer than 100
# followers. Display their UserID, Username, FullName, MessageCount, and
# FollowerCount

# %%
# %%sql
# SELECT
#     u.UserID,
#     u.Username,
#     u.FullName,
#     COUNT(DISTINCT m.MessageID) AS MessageCount,
#     COUNT(DISTINCT f.FollowerID) AS FollowerCount
# FROM
#     users u
# LEFT JOIN directmessages m
# ON u.UserID = m.SenderID
# LEFT JOIN followers f
# ON u.UserID = f.FollowedUserID
# GROUP BY
#     u.UserID, u.Username, u.FullName
# HAVING
#     FollowerCount < 100
# ORDER BY
#     MessageCount DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 5 rows affected.
# [(148.0, 'carolyn81', 'Tracy Mccall', 4, 2),
#  (210.0, 'burnsphillip', 'Ethan Reyes', 4, 0),
#  (303.0, 'camposjulia', 'Felicia Moody', 4, 1),
#  (381.0, 'jamesrichards', 'Mr. Larry Oliver', 4, 1),
#  (413.0, 'huffmanmegan', 'Jeremy Holt', 4, 0)]

# %% [markdown]
# ## 11. Scenario Q11
# ### Identify Users Who Have Not Engaged Recently
# Twitter aims to maintain high user engagement levels on its platform. Identifying users
# who have not engaged in any activities recently can help Twitter develop targeted
# strategies to re-engage these users and improve overall platform activity.
# Specific Task:
# List the UserID, Username, and FullName of users who have not sent messages, or
# tweets in the last 30 days.

# %%
# %%sql
# SELECT
#     u.UserID, u.Username, u.FullName
# FROM
#     users u
# WHERE u.UserID NOT IN
#     (
#         SELECT dm.SenderID
#         FROM directmessages dm
#         WHERE dm.`Timestamp` >= DATE_SUB(CURDATE(), INTERVAL 30 DAY)
#
#         UNION
#
#         SELECT t.UserID
#         FROM tweets t
#         WHERE t.`Timestamp` >= DATE_SUB(CURDATE(), INTERVAL 30 DAY)
#     );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 500 rows affected.
# [(1.0, 'hernandezelizabeth', 'Gary Murray'),
#  (2.0, 'joseph66', 'Sydney Taylor'),
#  (3.0, 'charlesjohnson', 'Maria Mckay'),
#  (4.0, 'tinakelly', 'Laura Taylor'),
#  (5.0, 'hubbardkelly', 'Joshua Jones'),
#  (6.0, 'fmckee', 'Michael Tran'),
#  (7.0, 'jasmineberry', 'Mark James'),
#  (8.0, 'katherinerogers', 'Stacy Chan'),
#  (9.0, 'jordansusan', 'William Edwards'),
#  (10.0, 'davisgina', 'Teresa Carr'),
#  (11.0, 'tashley', 'Nicole Davis'),
#  (12.0, 'kelli25', 'Scott White'),
#  (13.0, 'aaronbutler', 'George Holt'),
#  (14.0, 'iperez', 'Carla Jordan'),
#  (15.0, 'ythompson', 'April Turner'),
#  (16.0, 'david76', 'Brandi Quinn'),
#  (17.0, 'meghan35', 'Megan Perez'),
#  (18.0, 'joneskaren', 'Melissa Monroe'),
#  (19.0, 'trevorstewart', 'Brandy Hall'),
#  (20.0, 'lopezwhitney', 'Brett Wheeler'),
#  (21.0, 'cbaker', 'Robin Bailey'),
#  (22.0, 'donna98', 'Brittany Valenzuela'),
#  (23.0, 'mirandadaniel', 'Kenneth Murphy'),
#  (24.0, 'christinastevens', 'Ryan Martin'),
#  (25.0, 'andersonrichard', 'Pamela Johnson'),
#  (26.0, 'reyesmark', 'Jason Villegas'),
#  (27.0, 'vpierce', 'Anne Lopez'),
#  (28.0, 'john25', 'Cynthia Wyatt'),
#  (29.0, 'edwardhooper', 'David Franco'),
#  (30.0, 'robertscarrie', 'Mary Elliott'),
#  (31.0, 'cgardner', 'Jessica Hansen'),
#  (32.0, 'stephanie11', 'Dustin Palmer'),
#  (33.0, 'tamara12', 'Courtney Snyder'),
#  (34.0, 'rogerskaren', 'Sara Norman'),
#  (35.0, 'martinezkeith', 'Samantha Richards'),
#  (36.0, 'kyleholmes', 'Kerri Fernandez'),
#  (37.0, 'burkelogan', 'Heather Williams'),
#  (38.0, 'tadkins', 'Amber Watts'),
#  (39.0, 'jonesdavid', 'Alexander Wilson'),
#  (40.0, 'thomasjeffery', 'Bradley Berg'),
#  (41.0, 'meyersnathan', 'John Martinez'),
#  (42.0, 'twagner', 'Amanda Johnston'),
#  (43.0, 'timothymoore', 'Tina King'),
#  (44.0, 'mcmahonanna', 'Morgan Jackson'),
#  (45.0, 'robertvaughn', 'James Cook'),
#  (46.0, 'sean36', 'Charles Robinson'),
#  (47.0, 'hamiltonkarla', 'Travis Gallegos'),
#  (48.0, 'smithalexis', 'Christina Powell'),
#  (49.0, 'francoalexandra', 'Colleen Riley'),
#  (50.0, 'ricky52', 'Kimberly Gonzalez'),
#  (51.0, 'davidjones', 'Miguel Bailey'),
#  (52.0, 'debrabranch', 'Justin Baker'),
#  (53.0, 'currynathaniel', 'Cory Murphy'),
#  (54.0, 'christopher17', 'Adriana Howard'),
#  (55.0, 'shermanmatthew', 'Travis Walker'),
#  (56.0, 'ariel63', 'Kristen Fowler'),
#  (57.0, 'bakermarcus', 'Daniel Wright'),
#  (58.0, 'melissaclayton', 'John Adams'),
#  (59.0, 'laurasparks', 'Jennifer Smith'),
#  (60.0, 'rmeyers', 'James York'),
#  (61.0, 'ashley82', 'Jeremy Bradford'),
#  (62.0, 'kevin45', 'Jeffrey Carpenter'),
#  (63.0, 'laura32', 'Jennifer Liu'),
#  (64.0, 'johnlee', 'Rachel Rose'),
#  (65.0, 'wfaulkner', 'Teresa Shaw'),
#  (66.0, 'jeanshaw', 'Jennifer Garrett'),
#  (67.0, 'smithlaura', 'Adam Phillips'),
#  (68.0, 'ccook', 'Kimberly Estrada'),
#  (69.0, 'kimberlydennis', 'Heather Small'),
#  (70.0, 'rebeccagarcia', 'Allison Velasquez'),
#  (71.0, 'uharrison', 'Erika Reyes'),
#  (72.0, 'cindyhiggins', 'Brooke Gomez'),
#  (73.0, 'ecarpenter', 'James Pratt'),
#  (74.0, 'woodsdonald', 'Taylor Brown'),
#  (75.0, 'scott39', 'Keith Wall'),
#  (76.0, 'orodriguez', 'David Meyer'),
#  (77.0, 'joshuabrady', 'Whitney Maddox'),
#  (78.0, 'yflores', 'Denise Case'),
#  (79.0, 'parkerjamie', 'Rhonda Phillips'),
#  (80.0, 'tayloralexis', 'Lisa Davis'),
#  (81.0, 'warrenvictoria', 'Scott Davis'),
#  (82.0, 'christielarson', 'Deanna Farmer'),
#  (83.0, 'jeremysandoval', 'Edward Summers'),
#  (84.0, 'adamblake', 'Bryan Rogers'),
#  (85.0, 'maldonadoeric', 'John Vazquez'),
#  (86.0, 'owensshannon', 'Jamie Smith'),
#  (87.0, 'davidgarza', 'Emily Hall'),
#  (88.0, 'andrew18', 'Kristopher Williams'),
#  (89.0, 'lewisvalerie', 'Brian Warren'),
#  (90.0, 'jeffreymorrow', 'Mike Boone'),
#  (91.0, 'andersonnicole', 'Sarah Herrera'),
#  (92.0, 'maldonadoanthony', 'Gregory Cobb'),
#  (93.0, 'alexandraward', 'Jordan Brown'),
#  (94.0, 'garymckinney', 'Kimberly Rodriguez'),
#  (95.0, 'ryanadams', 'Christopher Williams'),
#  (96.0, 'cynthiamcdowell', 'Charles Carrillo'),
#  (97.0, 'xtorres', 'Jillian Lane'),
#  (98.0, 'sandra07', 'Hannah Greene'),
#  (99.0, 'brownkristina', 'Cody Mclean'),
#  (100.0, 'rmartin', 'Jessica Carpenter'),
#  (101.0, 'taylorsteve', 'Ebony Rush'),
#  (102.0, 'turnerjames', 'Michael Bradshaw'),
#  (103.0, 'katie81', 'Marissa Allen'),
#  (104.0, 'scott82', 'Anthony Burns'),
#  (105.0, 'becky91', 'Jacob Young'),
#  (106.0, 'mmonroe', 'Gregory Jordan'),
#  (107.0, 'zmason', 'Margaret Wallace'),
#  (108.0, 'clarkglenn', 'Adam Christensen'),
#  (109.0, 'lauriewheeler', 'Jack Martin'),
#  (110.0, 'victorburns', 'Terry Miranda'),
#  (111.0, 'sharon53', 'Willie Nash'),
#  (112.0, 'joshua55', 'Sheila Robinson'),
#  (113.0, 'stevencruz', 'Jennifer Perry'),
#  (114.0, 'smithmary', 'Stephen Moran'),
#  (115.0, 'jthornton', 'Megan Smith'),
#  (116.0, 'mccoyalyssa', 'Sherry Robinson'),
#  (117.0, 'mcdowellandrew', 'Donald Collier'),
#  (118.0, 'janderson', 'Vanessa Benjamin'),
#  (119.0, 'michaelamartinez', 'Kelly Rich'),
#  (120.0, 'jwalker', 'Randy Baker'),
#  (121.0, 'smithjustin', 'Vincent Miller'),
#  (122.0, 'jason12', 'Elizabeth Hill'),
#  (123.0, 'juliecox', 'James Huber'),
#  (124.0, 'mwebster', 'Mrs. Erika Marshall MD'),
#  (125.0, 'ecruz', 'David Waters'),
#  (126.0, 'trevorbarnes', 'Stephen Tran'),
#  (127.0, 'brandiberger', 'Carolyn Smith'),
#  (128.0, 'deckeralexis', 'David Moss'),
#  (129.0, 'xfitzgerald', 'Paul Henry'),
#  (130.0, 'randydavis', 'Jason Wright'),
#  (131.0, 'michael75', 'Mark Bridges'),
#  (132.0, 'qparks', 'Barbara Rogers'),
#  (133.0, 'mathewwatts', 'Patrick Khan'),
#  (134.0, 'stephanie87', 'Cheryl Phillips'),
#  (135.0, 'jessicaday', 'Eric Stark'),
#  (136.0, 'montgomeryhector', 'Alexa Vasquez PhD'),
#  (137.0, 'yhodges', 'Christopher Campbell'),
#  (138.0, 'kwilliams', 'Julie Garcia'),
#  (139.0, 'gsmith', 'Ariana Maxwell'),
#  (140.0, 'joshuahawkins', 'Eric Baldwin'),
#  (141.0, 'osbornegregory', 'Debra Mcfarland'),
#  (142.0, 'ruiztaylor', 'Scott Gibbs'),
#  (143.0, 'martinezjesse', 'Charles Hardin'),
#  (144.0, 'nicole76', 'Danielle Ingram'),
#  (145.0, 'keithmelton', 'Michelle Morris'),
#  (146.0, 'andrew05', 'Eric Horn'),
#  (147.0, 'vmonroe', 'Stephanie Jones'),
#  (148.0, 'carolyn81', 'Tracy Mccall'),
#  (149.0, 'brandi33', 'Steven Vazquez'),
#  (150.0, 'brittany96', 'Karen Lang'),
#  (151.0, 'brucematthew', 'Gregory Johnson'),
#  (152.0, 'matthew81', 'Brett Morales'),
#  (153.0, 'kanerussell', 'Kristen Wade'),
#  (154.0, 'williambeck', 'Brittany Camacho'),
#  (155.0, 'erica79', 'Raymond Paul'),
#  (156.0, 'devinchaney', 'Olivia Riley'),
#  (157.0, 'utorres', 'Ian Schneider'),
#  (158.0, 'erika23', 'Kristine Wheeler'),
#  (159.0, 'wcurry', 'Hector White'),
#  (160.0, 'ohernandez', 'Chris Little MD'),
#  (161.0, 'john47', 'Jaime Daniels'),
#  (162.0, 'stevenrodriguez', 'Stacey Keller'),
#  (163.0, 'awebb', 'Brandon Blake'),
#  (164.0, 'agonzales', 'Andrew Wise'),
#  (165.0, 'marciaatkinson', 'Holly Harrell DDS'),
#  (166.0, 'dylanlopez', 'James Pennington'),
#  (167.0, 'boydsean', 'Maria White'),
#  (168.0, 'matthewsbenjamin', 'Jocelyn Morton'),
#  (169.0, 'tknight', 'Scott Ferguson'),
#  (170.0, 'milesamanda', 'Steven Ray'),
#  (171.0, 'zburgess', 'Adam Adams'),
#  (172.0, 'sgarcia', 'Aaron James'),
#  (173.0, 'vicki07', 'Donald Lara'),
#  (174.0, 'mharrell', 'Vanessa Smith'),
#  (175.0, 'wendy53', 'Kevin Bean'),
#  (176.0, 'karenmiller', 'Christopher Zimmerman'),
#  (177.0, 'acostaalexis', 'Katelyn Johnson'),
#  (178.0, 'michaellawrence', 'Shelby Brown'),
#  (179.0, 'lisa54', 'Sara Cole'),
#  (180.0, 'powellcarrie', 'Richard Duran'),
#  (181.0, 'lyoung', 'Margaret Thomas'),
#  (182.0, 'danielgreene', 'Zoe Peterson'),
#  (183.0, 'jamierobinson', 'Bobby Wallace'),
#  (184.0, 'smithphilip', 'Tiffany Patterson DDS'),
#  (185.0, 'amanda42', 'Christopher Jones'),
#  (186.0, 'mark01', 'Christina Lewis'),
#  (187.0, 'torresbelinda', 'Kenneth Gibbs'),
#  (188.0, 'emily67', 'Sydney Lutz'),
#  (189.0, 'olowe', 'Dylan Carlson'),
#  (190.0, 'gmcneil', 'Lisa Jones'),
#  (191.0, 'richardjohnston', 'William Marshall'),
#  (192.0, 'woodalicia', 'Eric Garcia'),
#  (193.0, 'duncanjill', 'Joyce Jackson'),
#  (194.0, 'mckeedavid', 'Marcus Brown'),
#  (195.0, 'rclark', 'Felicia Hughes'),
#  (196.0, 'michaelwilliams', 'Steven Jones'),
#  (197.0, 'jennifer82', 'Paul Kemp'),
#  (198.0, 'zrice', 'Sharon Kim'),
#  (199.0, 'amber22', 'David Fields'),
#  (200.0, 'frankdaniel', 'Robert Moreno'),
#  (201.0, 'jacob67', 'Crystal Johnston'),
#  (202.0, 'stewartmaria', 'Chelsea Rogers'),
#  (203.0, 'murraymichael', 'Mary Bullock'),
#  (204.0, 'tiffany34', 'Derrick Henderson MD'),
#  (205.0, 'griffinjames', 'Cody Chavez'),
#  (206.0, 'campbellhector', 'John Mcdonald'),
#  (207.0, 'melindahouston', 'James Weaver'),
#  (208.0, 'urobinson', 'April Sanchez'),
#  (209.0, 'ronaldjones', 'Melanie Perez'),
#  (210.0, 'burnsphillip', 'Ethan Reyes'),
#  (211.0, 'brian24', 'Savannah Shaffer'),
#  (212.0, 'parrishmichelle', 'Katrina Thomas'),
#  (213.0, 'qcarter', 'Brian Rubio'),
#  (214.0, 'michael59', 'Andrew Glass'),
#  (215.0, 'aaron51', 'Steven Floyd'),
#  (216.0, 'maria94', 'Kevin Best'),
#  (217.0, 'xporter', 'Nicole Ryan'),
#  (218.0, 'dawnvaldez', 'Alicia Hurley'),
#  (219.0, 'fmarks', 'Desiree Shah'),
#  (220.0, 'crystal20', 'Julie Porter'),
#  (221.0, 'xdavis', 'Mrs. Cynthia Jones'),
#  (222.0, 'potternicole', 'Nathan Castillo'),
#  (223.0, 'margaret99', 'George Curry'),
#  (224.0, 'kristiperry', 'Alyssa Petersen'),
#  (225.0, 'hbaldwin', 'Michele Dixon'),
#  (226.0, 'oholmes', 'Richard Hodges'),
#  (227.0, 'baileyirwin', 'Alan Jones'),
#  (228.0, 'youngwilliam', 'Anthony James'),
#  (229.0, 'taylorlawrence', 'Linda Bryant'),
#  (230.0, 'andreclark', 'Austin Johnson'),
#  (231.0, 'amorales', 'Alexander Sellers'),
#  (232.0, 'michaelodom', 'Elizabeth Trevino'),
#  (233.0, 'carsonjames', 'William Flores'),
#  (234.0, 'gonzaleschristine', 'Tracy Vasquez'),
#  (235.0, 'alexandermiller', 'Tamara Montoya'),
#  (236.0, 'angeladuke', 'Brandy Vazquez'),
#  (237.0, 'milleranita', 'Timothy Morris'),
#  (238.0, 'davidallen', 'Lindsay Mendez'),
#  (239.0, 'susantaylor', 'Rachel Chan'),
#  (240.0, 'aprilmccoy', 'Kathleen Jenkins'),
#  (241.0, 'dkeller', 'Andrew Tapia'),
#  (242.0, 'mark37', 'Jorge Smith'),
#  (243.0, 'craig08', 'Victoria Marsh'),
#  (244.0, 'udennis', 'Leroy Murphy'),
#  (245.0, 'cheryl30', 'Michael Thornton'),
#  (246.0, 'dbaker', 'Ryan Jackson'),
#  (247.0, 'chenhenry', 'Nathan Morgan'),
#  (248.0, 'linda45', 'Monica Harper'),
#  (249.0, 'ojones', 'Dana George'),
#  (250.0, 'randy18', 'Joshua Fritz'),
#  (251.0, 'shafferjason', 'Stephanie Mcfarland'),
#  (252.0, 'john85', 'Melissa Hays'),
#  (253.0, 'tabbott', 'Samantha Douglas'),
#  (254.0, 'daveellis', 'Matthew Paul'),
#  (255.0, 'popemichael', 'Paul Li'),
#  (256.0, 'amberhartman', 'Ernest Garcia'),
#  (257.0, 'twatson', 'Tim Owens'),
#  (258.0, 'christopher66', 'James Gomez'),
#  (259.0, 'dhernandez', 'Christopher Villanueva'),
#  (260.0, 'tami33', 'Karen West'),
#  (261.0, 'nicholaschase', 'Veronica Hopkins'),
#  (262.0, 'floresangela', 'Amber Lee'),
#  (263.0, 'dan94', 'Jeffrey Stone'),
#  (264.0, 'kimjoshua', 'Heather Adams'),
#  (265.0, 'msmith', 'Brenda Fox'),
#  (266.0, 'hlawrence', 'Isabel Gamble'),
#  (267.0, 'awright', 'Anna Banks'),
#  (268.0, 'rachelflores', 'Michelle Myers MD'),
#  (269.0, 'john52', 'Mark Crawford'),
#  (270.0, 'bobby18', 'Jessica Weaver'),
#  (271.0, 'amy01', 'Kathryn Oneill'),
#  (272.0, 'steven35', 'Samuel Tucker'),
#  (273.0, 'alice42', 'Ross Underwood'),
#  (274.0, 'cjackson', 'Miranda Gray'),
#  (275.0, 'omooney', 'Sean Gonzalez'),
#  (276.0, 'bishoptrevor', 'Michael Thompson'),
#  (277.0, 'nicole35', 'Sarah Doyle'),
#  (278.0, 'padams', 'Luis Olson'),
#  (279.0, 'ygregory', 'Caleb Gibson'),
#  (280.0, 'megan23', 'Philip Frey'),
#  (281.0, 'brittneylam', 'Randall Vaughan'),
#  (282.0, 'llee', 'Kimberly Burton'),
#  (283.0, 'steven93', 'Mary Santana'),
#  (284.0, 'ann72', 'Kristin Moore'),
#  (285.0, 'mary06', 'Shannon Farrell'),
#  (286.0, 'danielwallace', 'Kathryn King'),
#  (287.0, 'brooksdaniel', 'Jeffrey Roberts'),
#  (288.0, 'patrick40', 'Austin Miranda MD'),
#  (289.0, 'billparker', 'Joshua Wagner'),
#  (290.0, 'christopherkerr', 'David Hill'),
#  (291.0, 'garyowens', 'Carol Beck'),
#  (292.0, 'browncynthia', 'Charles Taylor'),
#  (293.0, 'aedwards', 'Kathleen Travis'),
#  (294.0, 'sarah27', 'Shane Williams'),
#  (295.0, 'walter08', 'Barry Gilbert'),
#  (296.0, 'austin10', 'Brandon Austin'),
#  (297.0, 'scott04', 'Tara Mora'),
#  (298.0, 'xwilliams', 'Nicholas Garner'),
#  (299.0, 'kmerritt', 'Paul Byrd'),
#  (300.0, 'michael20', 'Penny Curtis'),
#  (301.0, 'nathangriffin', 'Amber Jacobs'),
#  (302.0, 'juliahines', 'Thomas Lopez'),
#  (303.0, 'camposjulia', 'Felicia Moody'),
#  (304.0, 'philip33', 'Robert Hudson'),
#  (305.0, 'jason06', 'Dennis Davis'),
#  (306.0, 'cknapp', 'Kristin Luna'),
#  (307.0, 'ljohns', 'Albert Ayala'),
#  (308.0, 'douglas75', 'Mary Sweeney'),
#  (309.0, 'hollandjoshua', 'Angel Moreno'),
#  (310.0, 'morrisonmelissa', 'Judy Wilson'),
#  (311.0, 'millerrichard', 'Suzanne Watson'),
#  (312.0, 'klinepenny', 'Mrs. Amber Santana'),
#  (313.0, 'scott99', 'Rebecca Dougherty'),
#  (314.0, 'jonathan30', 'Alyssa Fields'),
#  (315.0, 'stevenpowell', 'Mark Nelson'),
#  (316.0, 'rhoffman', 'Sandra Rowe'),
#  (317.0, 'cmiller', 'Sarah Henderson'),
#  (318.0, 'lyonsalex', 'Andre Johnson'),
#  (319.0, 'karenjenkins', 'Robert Martinez'),
#  (320.0, 'melissabrown', 'Brandy Carpenter'),
#  (321.0, 'bryceguerra', 'Tonya Andrews'),
#  (322.0, 'erika27', 'Sarah Anderson'),
#  (323.0, 'martinezjennifer', 'Rachel Willis'),
#  (324.0, 'stephanie82', 'Tasha Campbell'),
#  (325.0, 'bmorales', 'Cheryl Vance'),
#  (326.0, 'jordanphillip', 'Erin Harrison'),
#  (327.0, 'cgibson', 'Angel Lawson'),
#  (328.0, 'tammy97', 'Tammy Mack'),
#  (329.0, 'nancyjensen', 'Kayla Franklin'),
#  (330.0, 'charleslane', 'John Ortega'),
#  (331.0, 'agreen', 'Olivia Garner'),
#  (332.0, 'martinezsteven', 'Kimberly Nelson'),
#  (333.0, 'debraandrews', 'Renee Hicks'),
#  (334.0, 'cindyhowell', 'Andrea Oliver'),
#  (335.0, 'trivas', 'Stacey Brown MD'),
#  (336.0, 'mcdanielraymond', 'Geoffrey Spencer'),
#  (337.0, 'btodd', 'Gregory Ware'),
#  (338.0, 'donnapotter', 'Mrs. Holly Barnes'),
#  (339.0, 'kimberly29', 'Cody Blankenship'),
#  (340.0, 'fisherjason', 'Amber Alexander'),
#  (341.0, 'kenneth88', 'Miguel Conrad'),
#  (342.0, 'lsmith', 'Darlene Marshall'),
#  (343.0, 'katherinesmith', 'Mark Jones'),
#  (344.0, 'donald92', 'Natasha Wilson'),
#  (345.0, 'brandonjackson', 'Alexander Rollins'),
#  (346.0, 'moniquemorse', 'Robert Kramer'),
#  (347.0, 'bcampbell', 'James Snow'),
#  (348.0, 'rogerscharles', 'Melissa Guzman'),
#  (349.0, 'ijohnson', 'Ronald Jones'),
#  (350.0, 'floreschristopher', 'Thomas Mcdonald'),
#  (351.0, 'gregorybrendan', 'Jessica James'),
#  (352.0, 'jillian46', 'Amy Lee'),
#  (353.0, 'hickmancarrie', 'Tina Lopez'),
#  (354.0, 'emilymiles', 'Robert Brown'),
#  (355.0, 'kpatterson', 'Robert Terry'),
#  (356.0, 'briggsbradley', 'Cynthia Brown'),
#  (357.0, 'sheajames', 'Gina Dennis'),
#  (358.0, 'garrett13', 'Roger Hughes'),
#  (359.0, 'samantha93', 'Joseph Cline'),
#  (360.0, 'riveracolleen', 'Andrew Green'),
#  (361.0, 'gutierrezryan', 'Jennifer Fox'),
#  (362.0, 'jacksonkelly', 'Jerry Hoover'),
#  (363.0, 'evansimmons', 'Brandon Mosley'),
#  (364.0, 'chavezbenjamin', 'Jillian Davis'),
#  (365.0, 'russell80', 'Austin Hayes'),
#  (366.0, 'lmartin', 'Monica Davidson'),
#  (367.0, 'suzanne57', 'Melissa Turner'),
#  (368.0, 'tonyajones', 'Jose Moore'),
#  (369.0, 'rlynch', 'Tyler Wilkerson'),
#  (370.0, 'wbrown', 'Angela Carroll'),
#  (371.0, 'sarasanders', 'Carlos Hess'),
#  (372.0, 'nortiz', 'James Hernandez'),
#  (373.0, 'annagonzalez', 'Caitlin Johnson'),
#  (374.0, 'rolsen', 'Kimberly Williams'),
#  (375.0, 'uholder', 'John Martin'),
#  (376.0, 'levi67', 'Jody Benjamin'),
#  (377.0, 'sandrabarnes', 'Kyle Harris'),
#  (378.0, 'jamiehodges', 'Sheryl Baker'),
#  (379.0, 'normanstephanie', 'Randy Ross'),
#  (380.0, 'austin82', 'Thomas Hunter'),
#  (381.0, 'jamesrichards', 'Mr. Larry Oliver'),
#  (382.0, 'lscott', 'John Patel'),
#  (383.0, 'cooleyruth', 'Justin Carroll'),
#  (384.0, 'warnerchristopher', 'Brandon Fox'),
#  (385.0, 'melissaholloway', 'Michael Pham'),
#  (386.0, 'sharrison', 'Rachel Webster'),
#  (387.0, 'conwayalex', 'Melvin Smith'),
#  (388.0, 'cindywilliams', 'Lisa Grant'),
#  (389.0, 'christina53', 'Patrick Coleman'),
#  (390.0, 'handerson', 'Steven Perez'),
#  (391.0, 'hsantos', 'Caitlyn Smith'),
#  (392.0, 'katrinareed', 'Kimberly Chase'),
#  (393.0, 'anelson', 'Jason Greer'),
#  (394.0, 'theodorebarnes', 'Kelly Jackson'),
#  (395.0, 'pvillegas', 'Jennifer Thomas'),
#  (396.0, 'esparzacarlos', 'Thomas Richardson'),
#  (397.0, 'joseph47', 'Douglas Nichols'),
#  (398.0, 'brianaryan', 'Jon Russell'),
#  (399.0, 'hannah50', 'Christopher Rodriguez'),
#  (400.0, 'kfreeman', 'Mrs. Ashley Rodriguez'),
#  (401.0, 'bjimenez', 'Traci Mejia'),
#  (402.0, 'warren27', 'Kathryn Perez'),
#  (403.0, 'hicksjanet', 'Miss Carol Flores'),
#  (404.0, 'collinsmaria', 'Albert Williams'),
#  (405.0, 'aprillee', 'Amanda Howard'),
#  (406.0, 'dylanharper', 'Timothy Mays'),
#  (407.0, 'whitejessica', 'Larry Jones'),
#  (408.0, 'wdavidson', 'Amber Newman'),
#  (409.0, 'morenobrian', 'Jeffrey Thomas'),
#  (410.0, 'robert16', 'Travis Ballard'),
#  (411.0, 'stevensjoyce', 'Cody Colon'),
#  (412.0, 'gregorychristine', 'Ross Meadows'),
#  (413.0, 'huffmanmegan', 'Jeremy Holt'),
#  (414.0, 'cassidy57', 'Nicholas Thompson'),
#  (415.0, 'yherrera', 'Kelly Shepherd'),
#  (416.0, 'christopherpatterson', 'Ruben Harris'),
#  (417.0, 'heather32', 'Lorraine Webb'),
#  (418.0, 'thomas97', 'Andrew Roberts'),
#  (419.0, 'colleen10', 'Troy Fitzgerald'),
#  (420.0, 'sanchezamber', 'Melissa Mack'),
#  (421.0, 'fieldscynthia', 'Julie Munoz'),
#  (422.0, 'floydcindy', 'Ashley Juarez'),
#  (423.0, 'dochoa', 'Adam Livingston'),
#  (424.0, 'elopez', 'Duane Everett'),
#  (425.0, 'dwong', 'Holly Larson'),
#  (426.0, 'lwilliams', 'Savannah Noble'),
#  (427.0, 'dianeneal', 'Veronica Flores'),
#  (428.0, 'matthewwallace', 'Rebecca Mendoza'),
#  (429.0, 'yolandaluna', 'Gregory Ramos'),
#  (430.0, 'nhansen', 'Kimberly Stewart'),
#  (431.0, 'stevenfrancis', 'James Brandt'),
#  (432.0, 'melaniecameron', 'Madison Miller'),
#  (433.0, 'dwhite', 'Jennifer Larson'),
#  (434.0, 'ksmith', 'Robert Brown'),
#  (435.0, 'campbelldebbie', 'Vanessa Morrison'),
#  (436.0, 'vsims', 'Scott Bruce'),
#  (437.0, 'lauramorgan', 'Aimee Hall'),
#  (438.0, 'fmitchell', 'Michael Walker'),
#  (439.0, 'johnalvarez', 'Daniel Lee'),
#  (440.0, 'collinsmatthew', 'Rebecca Powell'),
#  (441.0, 'chad61', 'Mark Robbins'),
#  (442.0, 'hcarney', 'Jeremy Lowery'),
#  (443.0, 'imiles', 'Linda Nichols'),
#  (444.0, 'jhall', 'Allison Harris'),
#  (445.0, 'stephanie41', 'Kevin Cook'),
#  (446.0, 'tanyamurphy', 'Denise Gibson'),
#  (447.0, 'tsexton', 'Kenneth Bradley'),
#  (448.0, 'kellywhite', 'Andre Jacobs'),
#  (449.0, 'dennis52', 'Beth Preston'),
#  (450.0, 'afoster', 'Allison Baker'),
#  (451.0, 'nathanyoung', 'Joshua Fuller'),
#  (452.0, 'jacqueline60', 'Corey Burton'),
#  (453.0, 'ugonzalez', 'Justin Flores'),
#  (454.0, 'lpineda', 'Dana Buckley'),
#  (455.0, 'troy41', 'Tammy Sanders'),
#  (456.0, 'fclark', 'Melinda Huynh'),
#  (457.0, 'johnsonantonio', 'Andrew Robertson'),
#  (458.0, 'galvanbarbara', 'Mia Welch'),
#  (459.0, 'bvargas', 'Craig Beck'),
#  (460.0, 'andrewsanchez', 'Brian Garza'),
#  (461.0, 'gkelly', 'Jeffrey Meadows'),
#  (462.0, 'michele67', 'Brandon Howard'),
#  (463.0, 'rileyvalerie', 'Linda Lewis'),
#  (464.0, 'harrismisty', 'Erin Rodriguez'),
#  (465.0, 'marshallkimberly', 'Michael Terry'),
#  (466.0, 'tmccarty', 'Laura Nguyen'),
#  (467.0, 'richard92', 'Autumn Sexton'),
#  (468.0, 'fullerjoshua', 'Madison Mata'),
#  (469.0, 'iallen', 'Samantha Young'),
#  (470.0, 'michellebrown', 'Paula Ho'),
#  (471.0, 'bridget38', 'Robert Cook'),
#  (472.0, 'smithshelley', 'John Glenn'),
#  (473.0, 'lwillis', 'Jennifer Lopez'),
#  (474.0, 'fryan', 'Thomas Steele'),
#  (475.0, 'mrodgers', 'Steven Perry'),
#  (476.0, 'triciacrawford', 'Charlene Brandt'),
#  (477.0, 'leestein', 'Jeffrey Williams'),
#  (478.0, 'grussell', 'Phyllis Anderson'),
#  (479.0, 'jessica49', 'Roger Tanner'),
#  (480.0, 'kathleengibson', 'Michael Tanner'),
#  (481.0, 'fisherandrew', 'Christine Hanson'),
#  (482.0, 'johnsonjason', 'Crystal Coleman'),
#  (483.0, 'bryandavidson', 'Adam Weiss'),
#  (484.0, 'nicolekeith', 'Leslie Diaz'),
#  (485.0, 'taylorann', 'Christopher Willis'),
#  (486.0, 'carljohnson', 'Nathan Cortez'),
#  (487.0, 'misty24', 'David Stephens'),
#  (488.0, 'vincentmadden', 'Angel Moore'),
#  (489.0, 'nguyenrandy', 'Jillian Duran'),
#  (490.0, 'robert62', 'Barbara Brown'),
#  (491.0, 'johnsonmonica', 'Cheyenne Aguirre'),
#  (492.0, 'leah52', 'Lindsey Burns'),
#  (493.0, 'markcobb', 'Robert Holt'),
#  (494.0, 'athompson', 'Julie Hudson'),
#  (495.0, 'jordan59', 'Hannah Rice'),
#  (496.0, 'nwagner', 'Brianna Miller'),
#  (497.0, 'amanda32', 'Joshua Harrison'),
#  (498.0, 'carolbanks', 'Anthony Potter'),
#  (499.0, 'blakekyle', 'Alexis Fletcher'),
#  (500.0, 'connieberry', 'Teresa Jackson')]

# %%
# %%sql
#
# SELECT
#     u.userID, u.username, u.Fullname
# FROM
#     users u
# WHERE NOT EXISTS
#     (
#         SELECT dm.SenderID
#         FROM directmessages dm
#         WHERE dm.SenderID = u.UserID AND
#         dm.`Timestamp` >= NOW() - INTERVAL 30 DAY AND
#         dm.`Timestamp` <= NOW()
#     )
# AND NOT EXISTS
#     (
#         SELECT t.UserID
#         FROM tweets t
#         WHERE t.userID = u.UserID AND
#         t.`Timestamp` >= NOW() - INTERVAL 30 DAY AND
#         t.`Timestamp` <= NOW()
#     );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 500 rows affected.
# [(1.0, 'hernandezelizabeth', 'Gary Murray'),
#  (2.0, 'joseph66', 'Sydney Taylor'),
#  (3.0, 'charlesjohnson', 'Maria Mckay'),
#  (4.0, 'tinakelly', 'Laura Taylor'),
#  (5.0, 'hubbardkelly', 'Joshua Jones'),
#  (6.0, 'fmckee', 'Michael Tran'),
#  (7.0, 'jasmineberry', 'Mark James'),
#  (8.0, 'katherinerogers', 'Stacy Chan'),
#  (9.0, 'jordansusan', 'William Edwards'),
#  (10.0, 'davisgina', 'Teresa Carr'),
#  (11.0, 'tashley', 'Nicole Davis'),
#  (12.0, 'kelli25', 'Scott White'),
#  (13.0, 'aaronbutler', 'George Holt'),
#  (14.0, 'iperez', 'Carla Jordan'),
#  (15.0, 'ythompson', 'April Turner'),
#  (16.0, 'david76', 'Brandi Quinn'),
#  (17.0, 'meghan35', 'Megan Perez'),
#  (18.0, 'joneskaren', 'Melissa Monroe'),
#  (19.0, 'trevorstewart', 'Brandy Hall'),
#  (20.0, 'lopezwhitney', 'Brett Wheeler'),
#  (21.0, 'cbaker', 'Robin Bailey'),
#  (22.0, 'donna98', 'Brittany Valenzuela'),
#  (23.0, 'mirandadaniel', 'Kenneth Murphy'),
#  (24.0, 'christinastevens', 'Ryan Martin'),
#  (25.0, 'andersonrichard', 'Pamela Johnson'),
#  (26.0, 'reyesmark', 'Jason Villegas'),
#  (27.0, 'vpierce', 'Anne Lopez'),
#  (28.0, 'john25', 'Cynthia Wyatt'),
#  (29.0, 'edwardhooper', 'David Franco'),
#  (30.0, 'robertscarrie', 'Mary Elliott'),
#  (31.0, 'cgardner', 'Jessica Hansen'),
#  (32.0, 'stephanie11', 'Dustin Palmer'),
#  (33.0, 'tamara12', 'Courtney Snyder'),
#  (34.0, 'rogerskaren', 'Sara Norman'),
#  (35.0, 'martinezkeith', 'Samantha Richards'),
#  (36.0, 'kyleholmes', 'Kerri Fernandez'),
#  (37.0, 'burkelogan', 'Heather Williams'),
#  (38.0, 'tadkins', 'Amber Watts'),
#  (39.0, 'jonesdavid', 'Alexander Wilson'),
#  (40.0, 'thomasjeffery', 'Bradley Berg'),
#  (41.0, 'meyersnathan', 'John Martinez'),
#  (42.0, 'twagner', 'Amanda Johnston'),
#  (43.0, 'timothymoore', 'Tina King'),
#  (44.0, 'mcmahonanna', 'Morgan Jackson'),
#  (45.0, 'robertvaughn', 'James Cook'),
#  (46.0, 'sean36', 'Charles Robinson'),
#  (47.0, 'hamiltonkarla', 'Travis Gallegos'),
#  (48.0, 'smithalexis', 'Christina Powell'),
#  (49.0, 'francoalexandra', 'Colleen Riley'),
#  (50.0, 'ricky52', 'Kimberly Gonzalez'),
#  (51.0, 'davidjones', 'Miguel Bailey'),
#  (52.0, 'debrabranch', 'Justin Baker'),
#  (53.0, 'currynathaniel', 'Cory Murphy'),
#  (54.0, 'christopher17', 'Adriana Howard'),
#  (55.0, 'shermanmatthew', 'Travis Walker'),
#  (56.0, 'ariel63', 'Kristen Fowler'),
#  (57.0, 'bakermarcus', 'Daniel Wright'),
#  (58.0, 'melissaclayton', 'John Adams'),
#  (59.0, 'laurasparks', 'Jennifer Smith'),
#  (60.0, 'rmeyers', 'James York'),
#  (61.0, 'ashley82', 'Jeremy Bradford'),
#  (62.0, 'kevin45', 'Jeffrey Carpenter'),
#  (63.0, 'laura32', 'Jennifer Liu'),
#  (64.0, 'johnlee', 'Rachel Rose'),
#  (65.0, 'wfaulkner', 'Teresa Shaw'),
#  (66.0, 'jeanshaw', 'Jennifer Garrett'),
#  (67.0, 'smithlaura', 'Adam Phillips'),
#  (68.0, 'ccook', 'Kimberly Estrada'),
#  (69.0, 'kimberlydennis', 'Heather Small'),
#  (70.0, 'rebeccagarcia', 'Allison Velasquez'),
#  (71.0, 'uharrison', 'Erika Reyes'),
#  (72.0, 'cindyhiggins', 'Brooke Gomez'),
#  (73.0, 'ecarpenter', 'James Pratt'),
#  (74.0, 'woodsdonald', 'Taylor Brown'),
#  (75.0, 'scott39', 'Keith Wall'),
#  (76.0, 'orodriguez', 'David Meyer'),
#  (77.0, 'joshuabrady', 'Whitney Maddox'),
#  (78.0, 'yflores', 'Denise Case'),
#  (79.0, 'parkerjamie', 'Rhonda Phillips'),
#  (80.0, 'tayloralexis', 'Lisa Davis'),
#  (81.0, 'warrenvictoria', 'Scott Davis'),
#  (82.0, 'christielarson', 'Deanna Farmer'),
#  (83.0, 'jeremysandoval', 'Edward Summers'),
#  (84.0, 'adamblake', 'Bryan Rogers'),
#  (85.0, 'maldonadoeric', 'John Vazquez'),
#  (86.0, 'owensshannon', 'Jamie Smith'),
#  (87.0, 'davidgarza', 'Emily Hall'),
#  (88.0, 'andrew18', 'Kristopher Williams'),
#  (89.0, 'lewisvalerie', 'Brian Warren'),
#  (90.0, 'jeffreymorrow', 'Mike Boone'),
#  (91.0, 'andersonnicole', 'Sarah Herrera'),
#  (92.0, 'maldonadoanthony', 'Gregory Cobb'),
#  (93.0, 'alexandraward', 'Jordan Brown'),
#  (94.0, 'garymckinney', 'Kimberly Rodriguez'),
#  (95.0, 'ryanadams', 'Christopher Williams'),
#  (96.0, 'cynthiamcdowell', 'Charles Carrillo'),
#  (97.0, 'xtorres', 'Jillian Lane'),
#  (98.0, 'sandra07', 'Hannah Greene'),
#  (99.0, 'brownkristina', 'Cody Mclean'),
#  (100.0, 'rmartin', 'Jessica Carpenter'),
#  (101.0, 'taylorsteve', 'Ebony Rush'),
#  (102.0, 'turnerjames', 'Michael Bradshaw'),
#  (103.0, 'katie81', 'Marissa Allen'),
#  (104.0, 'scott82', 'Anthony Burns'),
#  (105.0, 'becky91', 'Jacob Young'),
#  (106.0, 'mmonroe', 'Gregory Jordan'),
#  (107.0, 'zmason', 'Margaret Wallace'),
#  (108.0, 'clarkglenn', 'Adam Christensen'),
#  (109.0, 'lauriewheeler', 'Jack Martin'),
#  (110.0, 'victorburns', 'Terry Miranda'),
#  (111.0, 'sharon53', 'Willie Nash'),
#  (112.0, 'joshua55', 'Sheila Robinson'),
#  (113.0, 'stevencruz', 'Jennifer Perry'),
#  (114.0, 'smithmary', 'Stephen Moran'),
#  (115.0, 'jthornton', 'Megan Smith'),
#  (116.0, 'mccoyalyssa', 'Sherry Robinson'),
#  (117.0, 'mcdowellandrew', 'Donald Collier'),
#  (118.0, 'janderson', 'Vanessa Benjamin'),
#  (119.0, 'michaelamartinez', 'Kelly Rich'),
#  (120.0, 'jwalker', 'Randy Baker'),
#  (121.0, 'smithjustin', 'Vincent Miller'),
#  (122.0, 'jason12', 'Elizabeth Hill'),
#  (123.0, 'juliecox', 'James Huber'),
#  (124.0, 'mwebster', 'Mrs. Erika Marshall MD'),
#  (125.0, 'ecruz', 'David Waters'),
#  (126.0, 'trevorbarnes', 'Stephen Tran'),
#  (127.0, 'brandiberger', 'Carolyn Smith'),
#  (128.0, 'deckeralexis', 'David Moss'),
#  (129.0, 'xfitzgerald', 'Paul Henry'),
#  (130.0, 'randydavis', 'Jason Wright'),
#  (131.0, 'michael75', 'Mark Bridges'),
#  (132.0, 'qparks', 'Barbara Rogers'),
#  (133.0, 'mathewwatts', 'Patrick Khan'),
#  (134.0, 'stephanie87', 'Cheryl Phillips'),
#  (135.0, 'jessicaday', 'Eric Stark'),
#  (136.0, 'montgomeryhector', 'Alexa Vasquez PhD'),
#  (137.0, 'yhodges', 'Christopher Campbell'),
#  (138.0, 'kwilliams', 'Julie Garcia'),
#  (139.0, 'gsmith', 'Ariana Maxwell'),
#  (140.0, 'joshuahawkins', 'Eric Baldwin'),
#  (141.0, 'osbornegregory', 'Debra Mcfarland'),
#  (142.0, 'ruiztaylor', 'Scott Gibbs'),
#  (143.0, 'martinezjesse', 'Charles Hardin'),
#  (144.0, 'nicole76', 'Danielle Ingram'),
#  (145.0, 'keithmelton', 'Michelle Morris'),
#  (146.0, 'andrew05', 'Eric Horn'),
#  (147.0, 'vmonroe', 'Stephanie Jones'),
#  (148.0, 'carolyn81', 'Tracy Mccall'),
#  (149.0, 'brandi33', 'Steven Vazquez'),
#  (150.0, 'brittany96', 'Karen Lang'),
#  (151.0, 'brucematthew', 'Gregory Johnson'),
#  (152.0, 'matthew81', 'Brett Morales'),
#  (153.0, 'kanerussell', 'Kristen Wade'),
#  (154.0, 'williambeck', 'Brittany Camacho'),
#  (155.0, 'erica79', 'Raymond Paul'),
#  (156.0, 'devinchaney', 'Olivia Riley'),
#  (157.0, 'utorres', 'Ian Schneider'),
#  (158.0, 'erika23', 'Kristine Wheeler'),
#  (159.0, 'wcurry', 'Hector White'),
#  (160.0, 'ohernandez', 'Chris Little MD'),
#  (161.0, 'john47', 'Jaime Daniels'),
#  (162.0, 'stevenrodriguez', 'Stacey Keller'),
#  (163.0, 'awebb', 'Brandon Blake'),
#  (164.0, 'agonzales', 'Andrew Wise'),
#  (165.0, 'marciaatkinson', 'Holly Harrell DDS'),
#  (166.0, 'dylanlopez', 'James Pennington'),
#  (167.0, 'boydsean', 'Maria White'),
#  (168.0, 'matthewsbenjamin', 'Jocelyn Morton'),
#  (169.0, 'tknight', 'Scott Ferguson'),
#  (170.0, 'milesamanda', 'Steven Ray'),
#  (171.0, 'zburgess', 'Adam Adams'),
#  (172.0, 'sgarcia', 'Aaron James'),
#  (173.0, 'vicki07', 'Donald Lara'),
#  (174.0, 'mharrell', 'Vanessa Smith'),
#  (175.0, 'wendy53', 'Kevin Bean'),
#  (176.0, 'karenmiller', 'Christopher Zimmerman'),
#  (177.0, 'acostaalexis', 'Katelyn Johnson'),
#  (178.0, 'michaellawrence', 'Shelby Brown'),
#  (179.0, 'lisa54', 'Sara Cole'),
#  (180.0, 'powellcarrie', 'Richard Duran'),
#  (181.0, 'lyoung', 'Margaret Thomas'),
#  (182.0, 'danielgreene', 'Zoe Peterson'),
#  (183.0, 'jamierobinson', 'Bobby Wallace'),
#  (184.0, 'smithphilip', 'Tiffany Patterson DDS'),
#  (185.0, 'amanda42', 'Christopher Jones'),
#  (186.0, 'mark01', 'Christina Lewis'),
#  (187.0, 'torresbelinda', 'Kenneth Gibbs'),
#  (188.0, 'emily67', 'Sydney Lutz'),
#  (189.0, 'olowe', 'Dylan Carlson'),
#  (190.0, 'gmcneil', 'Lisa Jones'),
#  (191.0, 'richardjohnston', 'William Marshall'),
#  (192.0, 'woodalicia', 'Eric Garcia'),
#  (193.0, 'duncanjill', 'Joyce Jackson'),
#  (194.0, 'mckeedavid', 'Marcus Brown'),
#  (195.0, 'rclark', 'Felicia Hughes'),
#  (196.0, 'michaelwilliams', 'Steven Jones'),
#  (197.0, 'jennifer82', 'Paul Kemp'),
#  (198.0, 'zrice', 'Sharon Kim'),
#  (199.0, 'amber22', 'David Fields'),
#  (200.0, 'frankdaniel', 'Robert Moreno'),
#  (201.0, 'jacob67', 'Crystal Johnston'),
#  (202.0, 'stewartmaria', 'Chelsea Rogers'),
#  (203.0, 'murraymichael', 'Mary Bullock'),
#  (204.0, 'tiffany34', 'Derrick Henderson MD'),
#  (205.0, 'griffinjames', 'Cody Chavez'),
#  (206.0, 'campbellhector', 'John Mcdonald'),
#  (207.0, 'melindahouston', 'James Weaver'),
#  (208.0, 'urobinson', 'April Sanchez'),
#  (209.0, 'ronaldjones', 'Melanie Perez'),
#  (210.0, 'burnsphillip', 'Ethan Reyes'),
#  (211.0, 'brian24', 'Savannah Shaffer'),
#  (212.0, 'parrishmichelle', 'Katrina Thomas'),
#  (213.0, 'qcarter', 'Brian Rubio'),
#  (214.0, 'michael59', 'Andrew Glass'),
#  (215.0, 'aaron51', 'Steven Floyd'),
#  (216.0, 'maria94', 'Kevin Best'),
#  (217.0, 'xporter', 'Nicole Ryan'),
#  (218.0, 'dawnvaldez', 'Alicia Hurley'),
#  (219.0, 'fmarks', 'Desiree Shah'),
#  (220.0, 'crystal20', 'Julie Porter'),
#  (221.0, 'xdavis', 'Mrs. Cynthia Jones'),
#  (222.0, 'potternicole', 'Nathan Castillo'),
#  (223.0, 'margaret99', 'George Curry'),
#  (224.0, 'kristiperry', 'Alyssa Petersen'),
#  (225.0, 'hbaldwin', 'Michele Dixon'),
#  (226.0, 'oholmes', 'Richard Hodges'),
#  (227.0, 'baileyirwin', 'Alan Jones'),
#  (228.0, 'youngwilliam', 'Anthony James'),
#  (229.0, 'taylorlawrence', 'Linda Bryant'),
#  (230.0, 'andreclark', 'Austin Johnson'),
#  (231.0, 'amorales', 'Alexander Sellers'),
#  (232.0, 'michaelodom', 'Elizabeth Trevino'),
#  (233.0, 'carsonjames', 'William Flores'),
#  (234.0, 'gonzaleschristine', 'Tracy Vasquez'),
#  (235.0, 'alexandermiller', 'Tamara Montoya'),
#  (236.0, 'angeladuke', 'Brandy Vazquez'),
#  (237.0, 'milleranita', 'Timothy Morris'),
#  (238.0, 'davidallen', 'Lindsay Mendez'),
#  (239.0, 'susantaylor', 'Rachel Chan'),
#  (240.0, 'aprilmccoy', 'Kathleen Jenkins'),
#  (241.0, 'dkeller', 'Andrew Tapia'),
#  (242.0, 'mark37', 'Jorge Smith'),
#  (243.0, 'craig08', 'Victoria Marsh'),
#  (244.0, 'udennis', 'Leroy Murphy'),
#  (245.0, 'cheryl30', 'Michael Thornton'),
#  (246.0, 'dbaker', 'Ryan Jackson'),
#  (247.0, 'chenhenry', 'Nathan Morgan'),
#  (248.0, 'linda45', 'Monica Harper'),
#  (249.0, 'ojones', 'Dana George'),
#  (250.0, 'randy18', 'Joshua Fritz'),
#  (251.0, 'shafferjason', 'Stephanie Mcfarland'),
#  (252.0, 'john85', 'Melissa Hays'),
#  (253.0, 'tabbott', 'Samantha Douglas'),
#  (254.0, 'daveellis', 'Matthew Paul'),
#  (255.0, 'popemichael', 'Paul Li'),
#  (256.0, 'amberhartman', 'Ernest Garcia'),
#  (257.0, 'twatson', 'Tim Owens'),
#  (258.0, 'christopher66', 'James Gomez'),
#  (259.0, 'dhernandez', 'Christopher Villanueva'),
#  (260.0, 'tami33', 'Karen West'),
#  (261.0, 'nicholaschase', 'Veronica Hopkins'),
#  (262.0, 'floresangela', 'Amber Lee'),
#  (263.0, 'dan94', 'Jeffrey Stone'),
#  (264.0, 'kimjoshua', 'Heather Adams'),
#  (265.0, 'msmith', 'Brenda Fox'),
#  (266.0, 'hlawrence', 'Isabel Gamble'),
#  (267.0, 'awright', 'Anna Banks'),
#  (268.0, 'rachelflores', 'Michelle Myers MD'),
#  (269.0, 'john52', 'Mark Crawford'),
#  (270.0, 'bobby18', 'Jessica Weaver'),
#  (271.0, 'amy01', 'Kathryn Oneill'),
#  (272.0, 'steven35', 'Samuel Tucker'),
#  (273.0, 'alice42', 'Ross Underwood'),
#  (274.0, 'cjackson', 'Miranda Gray'),
#  (275.0, 'omooney', 'Sean Gonzalez'),
#  (276.0, 'bishoptrevor', 'Michael Thompson'),
#  (277.0, 'nicole35', 'Sarah Doyle'),
#  (278.0, 'padams', 'Luis Olson'),
#  (279.0, 'ygregory', 'Caleb Gibson'),
#  (280.0, 'megan23', 'Philip Frey'),
#  (281.0, 'brittneylam', 'Randall Vaughan'),
#  (282.0, 'llee', 'Kimberly Burton'),
#  (283.0, 'steven93', 'Mary Santana'),
#  (284.0, 'ann72', 'Kristin Moore'),
#  (285.0, 'mary06', 'Shannon Farrell'),
#  (286.0, 'danielwallace', 'Kathryn King'),
#  (287.0, 'brooksdaniel', 'Jeffrey Roberts'),
#  (288.0, 'patrick40', 'Austin Miranda MD'),
#  (289.0, 'billparker', 'Joshua Wagner'),
#  (290.0, 'christopherkerr', 'David Hill'),
#  (291.0, 'garyowens', 'Carol Beck'),
#  (292.0, 'browncynthia', 'Charles Taylor'),
#  (293.0, 'aedwards', 'Kathleen Travis'),
#  (294.0, 'sarah27', 'Shane Williams'),
#  (295.0, 'walter08', 'Barry Gilbert'),
#  (296.0, 'austin10', 'Brandon Austin'),
#  (297.0, 'scott04', 'Tara Mora'),
#  (298.0, 'xwilliams', 'Nicholas Garner'),
#  (299.0, 'kmerritt', 'Paul Byrd'),
#  (300.0, 'michael20', 'Penny Curtis'),
#  (301.0, 'nathangriffin', 'Amber Jacobs'),
#  (302.0, 'juliahines', 'Thomas Lopez'),
#  (303.0, 'camposjulia', 'Felicia Moody'),
#  (304.0, 'philip33', 'Robert Hudson'),
#  (305.0, 'jason06', 'Dennis Davis'),
#  (306.0, 'cknapp', 'Kristin Luna'),
#  (307.0, 'ljohns', 'Albert Ayala'),
#  (308.0, 'douglas75', 'Mary Sweeney'),
#  (309.0, 'hollandjoshua', 'Angel Moreno'),
#  (310.0, 'morrisonmelissa', 'Judy Wilson'),
#  (311.0, 'millerrichard', 'Suzanne Watson'),
#  (312.0, 'klinepenny', 'Mrs. Amber Santana'),
#  (313.0, 'scott99', 'Rebecca Dougherty'),
#  (314.0, 'jonathan30', 'Alyssa Fields'),
#  (315.0, 'stevenpowell', 'Mark Nelson'),
#  (316.0, 'rhoffman', 'Sandra Rowe'),
#  (317.0, 'cmiller', 'Sarah Henderson'),
#  (318.0, 'lyonsalex', 'Andre Johnson'),
#  (319.0, 'karenjenkins', 'Robert Martinez'),
#  (320.0, 'melissabrown', 'Brandy Carpenter'),
#  (321.0, 'bryceguerra', 'Tonya Andrews'),
#  (322.0, 'erika27', 'Sarah Anderson'),
#  (323.0, 'martinezjennifer', 'Rachel Willis'),
#  (324.0, 'stephanie82', 'Tasha Campbell'),
#  (325.0, 'bmorales', 'Cheryl Vance'),
#  (326.0, 'jordanphillip', 'Erin Harrison'),
#  (327.0, 'cgibson', 'Angel Lawson'),
#  (328.0, 'tammy97', 'Tammy Mack'),
#  (329.0, 'nancyjensen', 'Kayla Franklin'),
#  (330.0, 'charleslane', 'John Ortega'),
#  (331.0, 'agreen', 'Olivia Garner'),
#  (332.0, 'martinezsteven', 'Kimberly Nelson'),
#  (333.0, 'debraandrews', 'Renee Hicks'),
#  (334.0, 'cindyhowell', 'Andrea Oliver'),
#  (335.0, 'trivas', 'Stacey Brown MD'),
#  (336.0, 'mcdanielraymond', 'Geoffrey Spencer'),
#  (337.0, 'btodd', 'Gregory Ware'),
#  (338.0, 'donnapotter', 'Mrs. Holly Barnes'),
#  (339.0, 'kimberly29', 'Cody Blankenship'),
#  (340.0, 'fisherjason', 'Amber Alexander'),
#  (341.0, 'kenneth88', 'Miguel Conrad'),
#  (342.0, 'lsmith', 'Darlene Marshall'),
#  (343.0, 'katherinesmith', 'Mark Jones'),
#  (344.0, 'donald92', 'Natasha Wilson'),
#  (345.0, 'brandonjackson', 'Alexander Rollins'),
#  (346.0, 'moniquemorse', 'Robert Kramer'),
#  (347.0, 'bcampbell', 'James Snow'),
#  (348.0, 'rogerscharles', 'Melissa Guzman'),
#  (349.0, 'ijohnson', 'Ronald Jones'),
#  (350.0, 'floreschristopher', 'Thomas Mcdonald'),
#  (351.0, 'gregorybrendan', 'Jessica James'),
#  (352.0, 'jillian46', 'Amy Lee'),
#  (353.0, 'hickmancarrie', 'Tina Lopez'),
#  (354.0, 'emilymiles', 'Robert Brown'),
#  (355.0, 'kpatterson', 'Robert Terry'),
#  (356.0, 'briggsbradley', 'Cynthia Brown'),
#  (357.0, 'sheajames', 'Gina Dennis'),
#  (358.0, 'garrett13', 'Roger Hughes'),
#  (359.0, 'samantha93', 'Joseph Cline'),
#  (360.0, 'riveracolleen', 'Andrew Green'),
#  (361.0, 'gutierrezryan', 'Jennifer Fox'),
#  (362.0, 'jacksonkelly', 'Jerry Hoover'),
#  (363.0, 'evansimmons', 'Brandon Mosley'),
#  (364.0, 'chavezbenjamin', 'Jillian Davis'),
#  (365.0, 'russell80', 'Austin Hayes'),
#  (366.0, 'lmartin', 'Monica Davidson'),
#  (367.0, 'suzanne57', 'Melissa Turner'),
#  (368.0, 'tonyajones', 'Jose Moore'),
#  (369.0, 'rlynch', 'Tyler Wilkerson'),
#  (370.0, 'wbrown', 'Angela Carroll'),
#  (371.0, 'sarasanders', 'Carlos Hess'),
#  (372.0, 'nortiz', 'James Hernandez'),
#  (373.0, 'annagonzalez', 'Caitlin Johnson'),
#  (374.0, 'rolsen', 'Kimberly Williams'),
#  (375.0, 'uholder', 'John Martin'),
#  (376.0, 'levi67', 'Jody Benjamin'),
#  (377.0, 'sandrabarnes', 'Kyle Harris'),
#  (378.0, 'jamiehodges', 'Sheryl Baker'),
#  (379.0, 'normanstephanie', 'Randy Ross'),
#  (380.0, 'austin82', 'Thomas Hunter'),
#  (381.0, 'jamesrichards', 'Mr. Larry Oliver'),
#  (382.0, 'lscott', 'John Patel'),
#  (383.0, 'cooleyruth', 'Justin Carroll'),
#  (384.0, 'warnerchristopher', 'Brandon Fox'),
#  (385.0, 'melissaholloway', 'Michael Pham'),
#  (386.0, 'sharrison', 'Rachel Webster'),
#  (387.0, 'conwayalex', 'Melvin Smith'),
#  (388.0, 'cindywilliams', 'Lisa Grant'),
#  (389.0, 'christina53', 'Patrick Coleman'),
#  (390.0, 'handerson', 'Steven Perez'),
#  (391.0, 'hsantos', 'Caitlyn Smith'),
#  (392.0, 'katrinareed', 'Kimberly Chase'),
#  (393.0, 'anelson', 'Jason Greer'),
#  (394.0, 'theodorebarnes', 'Kelly Jackson'),
#  (395.0, 'pvillegas', 'Jennifer Thomas'),
#  (396.0, 'esparzacarlos', 'Thomas Richardson'),
#  (397.0, 'joseph47', 'Douglas Nichols'),
#  (398.0, 'brianaryan', 'Jon Russell'),
#  (399.0, 'hannah50', 'Christopher Rodriguez'),
#  (400.0, 'kfreeman', 'Mrs. Ashley Rodriguez'),
#  (401.0, 'bjimenez', 'Traci Mejia'),
#  (402.0, 'warren27', 'Kathryn Perez'),
#  (403.0, 'hicksjanet', 'Miss Carol Flores'),
#  (404.0, 'collinsmaria', 'Albert Williams'),
#  (405.0, 'aprillee', 'Amanda Howard'),
#  (406.0, 'dylanharper', 'Timothy Mays'),
#  (407.0, 'whitejessica', 'Larry Jones'),
#  (408.0, 'wdavidson', 'Amber Newman'),
#  (409.0, 'morenobrian', 'Jeffrey Thomas'),
#  (410.0, 'robert16', 'Travis Ballard'),
#  (411.0, 'stevensjoyce', 'Cody Colon'),
#  (412.0, 'gregorychristine', 'Ross Meadows'),
#  (413.0, 'huffmanmegan', 'Jeremy Holt'),
#  (414.0, 'cassidy57', 'Nicholas Thompson'),
#  (415.0, 'yherrera', 'Kelly Shepherd'),
#  (416.0, 'christopherpatterson', 'Ruben Harris'),
#  (417.0, 'heather32', 'Lorraine Webb'),
#  (418.0, 'thomas97', 'Andrew Roberts'),
#  (419.0, 'colleen10', 'Troy Fitzgerald'),
#  (420.0, 'sanchezamber', 'Melissa Mack'),
#  (421.0, 'fieldscynthia', 'Julie Munoz'),
#  (422.0, 'floydcindy', 'Ashley Juarez'),
#  (423.0, 'dochoa', 'Adam Livingston'),
#  (424.0, 'elopez', 'Duane Everett'),
#  (425.0, 'dwong', 'Holly Larson'),
#  (426.0, 'lwilliams', 'Savannah Noble'),
#  (427.0, 'dianeneal', 'Veronica Flores'),
#  (428.0, 'matthewwallace', 'Rebecca Mendoza'),
#  (429.0, 'yolandaluna', 'Gregory Ramos'),
#  (430.0, 'nhansen', 'Kimberly Stewart'),
#  (431.0, 'stevenfrancis', 'James Brandt'),
#  (432.0, 'melaniecameron', 'Madison Miller'),
#  (433.0, 'dwhite', 'Jennifer Larson'),
#  (434.0, 'ksmith', 'Robert Brown'),
#  (435.0, 'campbelldebbie', 'Vanessa Morrison'),
#  (436.0, 'vsims', 'Scott Bruce'),
#  (437.0, 'lauramorgan', 'Aimee Hall'),
#  (438.0, 'fmitchell', 'Michael Walker'),
#  (439.0, 'johnalvarez', 'Daniel Lee'),
#  (440.0, 'collinsmatthew', 'Rebecca Powell'),
#  (441.0, 'chad61', 'Mark Robbins'),
#  (442.0, 'hcarney', 'Jeremy Lowery'),
#  (443.0, 'imiles', 'Linda Nichols'),
#  (444.0, 'jhall', 'Allison Harris'),
#  (445.0, 'stephanie41', 'Kevin Cook'),
#  (446.0, 'tanyamurphy', 'Denise Gibson'),
#  (447.0, 'tsexton', 'Kenneth Bradley'),
#  (448.0, 'kellywhite', 'Andre Jacobs'),
#  (449.0, 'dennis52', 'Beth Preston'),
#  (450.0, 'afoster', 'Allison Baker'),
#  (451.0, 'nathanyoung', 'Joshua Fuller'),
#  (452.0, 'jacqueline60', 'Corey Burton'),
#  (453.0, 'ugonzalez', 'Justin Flores'),
#  (454.0, 'lpineda', 'Dana Buckley'),
#  (455.0, 'troy41', 'Tammy Sanders'),
#  (456.0, 'fclark', 'Melinda Huynh'),
#  (457.0, 'johnsonantonio', 'Andrew Robertson'),
#  (458.0, 'galvanbarbara', 'Mia Welch'),
#  (459.0, 'bvargas', 'Craig Beck'),
#  (460.0, 'andrewsanchez', 'Brian Garza'),
#  (461.0, 'gkelly', 'Jeffrey Meadows'),
#  (462.0, 'michele67', 'Brandon Howard'),
#  (463.0, 'rileyvalerie', 'Linda Lewis'),
#  (464.0, 'harrismisty', 'Erin Rodriguez'),
#  (465.0, 'marshallkimberly', 'Michael Terry'),
#  (466.0, 'tmccarty', 'Laura Nguyen'),
#  (467.0, 'richard92', 'Autumn Sexton'),
#  (468.0, 'fullerjoshua', 'Madison Mata'),
#  (469.0, 'iallen', 'Samantha Young'),
#  (470.0, 'michellebrown', 'Paula Ho'),
#  (471.0, 'bridget38', 'Robert Cook'),
#  (472.0, 'smithshelley', 'John Glenn'),
#  (473.0, 'lwillis', 'Jennifer Lopez'),
#  (474.0, 'fryan', 'Thomas Steele'),
#  (475.0, 'mrodgers', 'Steven Perry'),
#  (476.0, 'triciacrawford', 'Charlene Brandt'),
#  (477.0, 'leestein', 'Jeffrey Williams'),
#  (478.0, 'grussell', 'Phyllis Anderson'),
#  (479.0, 'jessica49', 'Roger Tanner'),
#  (480.0, 'kathleengibson', 'Michael Tanner'),
#  (481.0, 'fisherandrew', 'Christine Hanson'),
#  (482.0, 'johnsonjason', 'Crystal Coleman'),
#  (483.0, 'bryandavidson', 'Adam Weiss'),
#  (484.0, 'nicolekeith', 'Leslie Diaz'),
#  (485.0, 'taylorann', 'Christopher Willis'),
#  (486.0, 'carljohnson', 'Nathan Cortez'),
#  (487.0, 'misty24', 'David Stephens'),
#  (488.0, 'vincentmadden', 'Angel Moore'),
#  (489.0, 'nguyenrandy', 'Jillian Duran'),
#  (490.0, 'robert62', 'Barbara Brown'),
#  (491.0, 'johnsonmonica', 'Cheyenne Aguirre'),
#  (492.0, 'leah52', 'Lindsey Burns'),
#  (493.0, 'markcobb', 'Robert Holt'),
#  (494.0, 'athompson', 'Julie Hudson'),
#  (495.0, 'jordan59', 'Hannah Rice'),
#  (496.0, 'nwagner', 'Brianna Miller'),
#  (497.0, 'amanda32', 'Joshua Harrison'),
#  (498.0, 'carolbanks', 'Anthony Potter'),
#  (499.0, 'blakekyle', 'Alexis Fletcher'),
#  (500.0, 'connieberry', 'Teresa Jackson')]

# %% [markdown]
# ## 12. Scenario Q12
# ### Find Most Popular Tweets Based on User Interaction
# Twitter wants to identify and promote the most popular tweets on its platform. A tweet’s
# popularity can be assessed by the number of likes, retweets, and mentions it receives.
# Highlighting popular tweets can enhance user engagement and attract more users to
# the platform.
# The task is to Identify the top 3 tweets that have received the most combined user
# interactions (likes, retweets, mentions). Display the TweetID, UserID (of the user who
# posted the tweet), Username, FullName, and the total count of interactions

# %%
# %%sql
# SELECT
#     u.UserID, u.Username, u.FullName,
#     t.TweetID,
#     COUNT(DISTINCT l.LikeID) AS LikeCount,
#     COUNT(DISTINCT rt.RetweetID) AS RetweetCount,
#     COUNT(DISTINCT men.MentionID) AS MentionCount,
#     (
#         COUNT(DISTINCT l.LikeID) +
#         COUNT(DISTINCT rt.RetweetID) +
#         COUNT(DISTINCT men.MentionID)
#     ) AS TotalCountInteractions
# FROM
#     users u
# LEFT JOIN tweets t
# ON u.UserID = t.UserID
# LEFT JOIN likes l
# ON t.TweetID = l.TweetID
# LEFT JOIN retweets rt
# ON t.TweetID = rt.OriginalTweetID
# LEFT JOIN mentions men
# ON t.TweetID = men.TweetID
# GROUP BY
#     u.UserID, u.Username, u.FullName, t.TweetID
# ORDER BY
#     TotalCountInteractions DESC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 3 rows affected.
# [(305.0, 'jason06', 'Dennis Davis', 245.0, 5, 2, 4, 11),
#  (83.0, 'jeremysandoval', 'Edward Summers', 426.0, 2, 4, 3, 9),
#  (44.0, 'mcmahonanna', 'Morgan Jackson', 217.0, 4, 3, 1, 8)]

# %% [markdown]
# ## 13. Scenario Q13
# ### Find Users Who Have Never Been Mentioned
# Twitter is interested in increasing interactions among users. The company wants to
# identify users who have never been mentioned by others so that it can encourage more
# interactions involving these users.
# The task is to retrieve a list of UserID, Username, and FullName of users who have
# never been mentioned in any tweets

# %%
# %%sql
# SELECT
#     u.UserID, u.Username, u.FullName
# FROM
#     users u
# WHERE NOT EXISTS
#     (
#         SELECT
#             men.MentionedUserID
#         FROM
#             mentions men
#         WHERE
#             men.MentionedUserID = u.UserID
#     );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 180 rows affected.
# [(2.0, 'joseph66', 'Sydney Taylor'),
#  (5.0, 'hubbardkelly', 'Joshua Jones'),
#  (6.0, 'fmckee', 'Michael Tran'),
#  (7.0, 'jasmineberry', 'Mark James'),
#  (8.0, 'katherinerogers', 'Stacy Chan'),
#  (11.0, 'tashley', 'Nicole Davis'),
#  (12.0, 'kelli25', 'Scott White'),
#  (16.0, 'david76', 'Brandi Quinn'),
#  (29.0, 'edwardhooper', 'David Franco'),
#  (30.0, 'robertscarrie', 'Mary Elliott'),
#  (31.0, 'cgardner', 'Jessica Hansen'),
#  (33.0, 'tamara12', 'Courtney Snyder'),
#  (35.0, 'martinezkeith', 'Samantha Richards'),
#  (38.0, 'tadkins', 'Amber Watts'),
#  (40.0, 'thomasjeffery', 'Bradley Berg'),
#  (43.0, 'timothymoore', 'Tina King'),
#  (50.0, 'ricky52', 'Kimberly Gonzalez'),
#  (55.0, 'shermanmatthew', 'Travis Walker'),
#  (57.0, 'bakermarcus', 'Daniel Wright'),
#  (60.0, 'rmeyers', 'James York'),
#  (61.0, 'ashley82', 'Jeremy Bradford'),
#  (63.0, 'laura32', 'Jennifer Liu'),
#  (64.0, 'johnlee', 'Rachel Rose'),
#  (65.0, 'wfaulkner', 'Teresa Shaw'),
#  (66.0, 'jeanshaw', 'Jennifer Garrett'),
#  (67.0, 'smithlaura', 'Adam Phillips'),
#  (69.0, 'kimberlydennis', 'Heather Small'),
#  (71.0, 'uharrison', 'Erika Reyes'),
#  (73.0, 'ecarpenter', 'James Pratt'),
#  (77.0, 'joshuabrady', 'Whitney Maddox'),
#  (79.0, 'parkerjamie', 'Rhonda Phillips'),
#  (83.0, 'jeremysandoval', 'Edward Summers'),
#  (84.0, 'adamblake', 'Bryan Rogers'),
#  (85.0, 'maldonadoeric', 'John Vazquez'),
#  (89.0, 'lewisvalerie', 'Brian Warren'),
#  (91.0, 'andersonnicole', 'Sarah Herrera'),
#  (92.0, 'maldonadoanthony', 'Gregory Cobb'),
#  (95.0, 'ryanadams', 'Christopher Williams'),
#  (97.0, 'xtorres', 'Jillian Lane'),
#  (98.0, 'sandra07', 'Hannah Greene'),
#  (101.0, 'taylorsteve', 'Ebony Rush'),
#  (102.0, 'turnerjames', 'Michael Bradshaw'),
#  (103.0, 'katie81', 'Marissa Allen'),
#  (104.0, 'scott82', 'Anthony Burns'),
#  (108.0, 'clarkglenn', 'Adam Christensen'),
#  (110.0, 'victorburns', 'Terry Miranda'),
#  (112.0, 'joshua55', 'Sheila Robinson'),
#  (117.0, 'mcdowellandrew', 'Donald Collier'),
#  (119.0, 'michaelamartinez', 'Kelly Rich'),
#  (125.0, 'ecruz', 'David Waters'),
#  (127.0, 'brandiberger', 'Carolyn Smith'),
#  (136.0, 'montgomeryhector', 'Alexa Vasquez PhD'),
#  (137.0, 'yhodges', 'Christopher Campbell'),
#  (139.0, 'gsmith', 'Ariana Maxwell'),
#  (140.0, 'joshuahawkins', 'Eric Baldwin'),
#  (142.0, 'ruiztaylor', 'Scott Gibbs'),
#  (145.0, 'keithmelton', 'Michelle Morris'),
#  (146.0, 'andrew05', 'Eric Horn'),
#  (147.0, 'vmonroe', 'Stephanie Jones'),
#  (148.0, 'carolyn81', 'Tracy Mccall'),
#  (151.0, 'brucematthew', 'Gregory Johnson'),
#  (153.0, 'kanerussell', 'Kristen Wade'),
#  (164.0, 'agonzales', 'Andrew Wise'),
#  (166.0, 'dylanlopez', 'James Pennington'),
#  (169.0, 'tknight', 'Scott Ferguson'),
#  (172.0, 'sgarcia', 'Aaron James'),
#  (173.0, 'vicki07', 'Donald Lara'),
#  (179.0, 'lisa54', 'Sara Cole'),
#  (182.0, 'danielgreene', 'Zoe Peterson'),
#  (189.0, 'olowe', 'Dylan Carlson'),
#  (193.0, 'duncanjill', 'Joyce Jackson'),
#  (196.0, 'michaelwilliams', 'Steven Jones'),
#  (202.0, 'stewartmaria', 'Chelsea Rogers'),
#  (206.0, 'campbellhector', 'John Mcdonald'),
#  (208.0, 'urobinson', 'April Sanchez'),
#  (210.0, 'burnsphillip', 'Ethan Reyes'),
#  (211.0, 'brian24', 'Savannah Shaffer'),
#  (214.0, 'michael59', 'Andrew Glass'),
#  (215.0, 'aaron51', 'Steven Floyd'),
#  (217.0, 'xporter', 'Nicole Ryan'),
#  (219.0, 'fmarks', 'Desiree Shah'),
#  (221.0, 'xdavis', 'Mrs. Cynthia Jones'),
#  (224.0, 'kristiperry', 'Alyssa Petersen'),
#  (225.0, 'hbaldwin', 'Michele Dixon'),
#  (226.0, 'oholmes', 'Richard Hodges'),
#  (230.0, 'andreclark', 'Austin Johnson'),
#  (232.0, 'michaelodom', 'Elizabeth Trevino'),
#  (233.0, 'carsonjames', 'William Flores'),
#  (234.0, 'gonzaleschristine', 'Tracy Vasquez'),
#  (238.0, 'davidallen', 'Lindsay Mendez'),
#  (239.0, 'susantaylor', 'Rachel Chan'),
#  (245.0, 'cheryl30', 'Michael Thornton'),
#  (247.0, 'chenhenry', 'Nathan Morgan'),
#  (250.0, 'randy18', 'Joshua Fritz'),
#  (253.0, 'tabbott', 'Samantha Douglas'),
#  (254.0, 'daveellis', 'Matthew Paul'),
#  (255.0, 'popemichael', 'Paul Li'),
#  (260.0, 'tami33', 'Karen West'),
#  (261.0, 'nicholaschase', 'Veronica Hopkins'),
#  (262.0, 'floresangela', 'Amber Lee'),
#  (264.0, 'kimjoshua', 'Heather Adams'),
#  (265.0, 'msmith', 'Brenda Fox'),
#  (269.0, 'john52', 'Mark Crawford'),
#  (270.0, 'bobby18', 'Jessica Weaver'),
#  (272.0, 'steven35', 'Samuel Tucker'),
#  (275.0, 'omooney', 'Sean Gonzalez'),
#  (278.0, 'padams', 'Luis Olson'),
#  (279.0, 'ygregory', 'Caleb Gibson'),
#  (280.0, 'megan23', 'Philip Frey'),
#  (282.0, 'llee', 'Kimberly Burton'),
#  (283.0, 'steven93', 'Mary Santana'),
#  (285.0, 'mary06', 'Shannon Farrell'),
#  (291.0, 'garyowens', 'Carol Beck'),
#  (292.0, 'browncynthia', 'Charles Taylor'),
#  (293.0, 'aedwards', 'Kathleen Travis'),
#  (294.0, 'sarah27', 'Shane Williams'),
#  (297.0, 'scott04', 'Tara Mora'),
#  (301.0, 'nathangriffin', 'Amber Jacobs'),
#  (302.0, 'juliahines', 'Thomas Lopez'),
#  (303.0, 'camposjulia', 'Felicia Moody'),
#  (307.0, 'ljohns', 'Albert Ayala'),
#  (309.0, 'hollandjoshua', 'Angel Moreno'),
#  (312.0, 'klinepenny', 'Mrs. Amber Santana'),
#  (314.0, 'jonathan30', 'Alyssa Fields'),
#  (315.0, 'stevenpowell', 'Mark Nelson'),
#  (325.0, 'bmorales', 'Cheryl Vance'),
#  (336.0, 'mcdanielraymond', 'Geoffrey Spencer'),
#  (338.0, 'donnapotter', 'Mrs. Holly Barnes'),
#  (344.0, 'donald92', 'Natasha Wilson'),
#  (345.0, 'brandonjackson', 'Alexander Rollins'),
#  (350.0, 'floreschristopher', 'Thomas Mcdonald'),
#  (351.0, 'gregorybrendan', 'Jessica James'),
#  (357.0, 'sheajames', 'Gina Dennis'),
#  (358.0, 'garrett13', 'Roger Hughes'),
#  (364.0, 'chavezbenjamin', 'Jillian Davis'),
#  (366.0, 'lmartin', 'Monica Davidson'),
#  (369.0, 'rlynch', 'Tyler Wilkerson'),
#  (371.0, 'sarasanders', 'Carlos Hess'),
#  (373.0, 'annagonzalez', 'Caitlin Johnson'),
#  (379.0, 'normanstephanie', 'Randy Ross'),
#  (381.0, 'jamesrichards', 'Mr. Larry Oliver'),
#  (391.0, 'hsantos', 'Caitlyn Smith'),
#  (395.0, 'pvillegas', 'Jennifer Thomas'),
#  (400.0, 'kfreeman', 'Mrs. Ashley Rodriguez'),
#  (403.0, 'hicksjanet', 'Miss Carol Flores'),
#  (405.0, 'aprillee', 'Amanda Howard'),
#  (407.0, 'whitejessica', 'Larry Jones'),
#  (408.0, 'wdavidson', 'Amber Newman'),
#  (409.0, 'morenobrian', 'Jeffrey Thomas'),
#  (413.0, 'huffmanmegan', 'Jeremy Holt'),
#  (414.0, 'cassidy57', 'Nicholas Thompson'),
#  (416.0, 'christopherpatterson', 'Ruben Harris'),
#  (417.0, 'heather32', 'Lorraine Webb'),
#  (418.0, 'thomas97', 'Andrew Roberts'),
#  (421.0, 'fieldscynthia', 'Julie Munoz'),
#  (424.0, 'elopez', 'Duane Everett'),
#  (427.0, 'dianeneal', 'Veronica Flores'),
#  (429.0, 'yolandaluna', 'Gregory Ramos'),
#  (435.0, 'campbelldebbie', 'Vanessa Morrison'),
#  (436.0, 'vsims', 'Scott Bruce'),
#  (440.0, 'collinsmatthew', 'Rebecca Powell'),
#  (443.0, 'imiles', 'Linda Nichols'),
#  (446.0, 'tanyamurphy', 'Denise Gibson'),
#  (451.0, 'nathanyoung', 'Joshua Fuller'),
#  (453.0, 'ugonzalez', 'Justin Flores'),
#  (460.0, 'andrewsanchez', 'Brian Garza'),
#  (463.0, 'rileyvalerie', 'Linda Lewis'),
#  (465.0, 'marshallkimberly', 'Michael Terry'),
#  (467.0, 'richard92', 'Autumn Sexton'),
#  (468.0, 'fullerjoshua', 'Madison Mata'),
#  (471.0, 'bridget38', 'Robert Cook'),
#  (473.0, 'lwillis', 'Jennifer Lopez'),
#  (480.0, 'kathleengibson', 'Michael Tanner'),
#  (481.0, 'fisherandrew', 'Christine Hanson'),
#  (484.0, 'nicolekeith', 'Leslie Diaz'),
#  (485.0, 'taylorann', 'Christopher Willis'),
#  (487.0, 'misty24', 'David Stephens'),
#  (492.0, 'leah52', 'Lindsey Burns'),
#  (498.0, 'carolbanks', 'Anthony Potter'),
#  (500.0, 'connieberry', 'Teresa Jackson')]

# %% [markdown]
# ## 14. Scenario Q14
# ##### Analyse the Average Number of Followers per User
# Twitter wants to analyse the average number of followers that users on the platform
# have. This will help Twitter understand the distribution of followers and identify whether
# the platform has a balanced user interaction or is dominated by a few users with a
# large number of followers. The task is to calculate the average number of followers
# that users on the platform have.

# %%
# %%sql
#
# SELECT
#     ROUND(AVG(FollowersCount), 2) AS AvgFollowersPerUser
# FROM (
#     SELECT
#         FollowedUserID AS UserID,
#         COUNT(FollowerUserID) AS FollowersCount
#     FROM Followers
#     GROUP BY FollowedUserID
# ) AS UserFollowers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/twitterdb
# 1 rows affected.
# [(Decimal('1.59'),)]
